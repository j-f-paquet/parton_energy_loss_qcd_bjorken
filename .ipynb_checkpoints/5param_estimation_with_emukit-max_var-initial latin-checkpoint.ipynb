# %%
import emcee
from scipy.optimize import minimize
import corner
import ptemcee
import subprocess
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import run_simple_energy_loss

# %%
simulation=run_simple_energy_loss.run_simulation

# %%
pT_range = (1, 10, 10) # Compute more observable than needed to avoid boundry unstabilities.
pT_obs = [3, 5, 7] # p_T Observables we will use for the analysis

# %%
from emukit.core import ParameterSpace, ContinuousParameter

# %%
prior_ranges= {'alpha_s':(0.05,0.5), 'exponent_inel':(-3,3), 'exponent_el':(-3,3), 'scale_inel':(0.1, 0.5), 'scale_el':(0.1, 0.5)}
true_values= {'alpha_s': 0.2, 'exponent_inel': -1, 'exponent_el': 1, 'scale_inel': 0.3, 'scale_el': 0.3}
name_to_position =  {'alpha_s':0, 'exponent_inel':1, 'exponent_el':2, 'scale_inel':3, 'scale_el':4}

# %%
# We will generate observable for these model parametr values and consider them as experimental data
# We will generate observables for these model parameter values and consider them as experimental data
truth = np.array([true_values['alpha_s'],  true_values['exponent_inel'],
                 true_values['exponent_el'],true_values['scale_inel'],true_values['scale_el']]).reshape(1,-1)

# %%
# Set seed for reproducibility.
seed = 42
np.random.seed(seed)

# Generate some synthetic data from the model.
x = np.array(pT_obs)
N = len(x)
obserr = 0.05 # Amplitude of noise term
obs = simulation(truth, *pT_range)[:,pT_obs] # True model
obs += obserr * np.random.randn(N) # Add some random noise

# Now plot it to see what the data looks like
fig, ax = plt.subplots(figsize=(8,8))

ax.errorbar(x.flatten(), obs.flatten(), yerr=obserr, fmt="xk", capsize=0)
#ax.plot(x.flatten(), obs.flatten(), "k", alpha=0.3, lw=3)
#ax.set_xlim(0, 10)
ax.set_xlabel(r"$p_T$")
ax.set_ylabel(r"$R_{AA}$")
ax.set_title('Experimental observations')
# Out:
# Working on 1/1 design
# /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning: dopri5: step size becomes too small
#   self.messages.get(istate, unexpected_istate_msg)))
# /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning: dopri5: larger nsteps is needed
#   self.messages.get(istate, unexpected_istate_msg)))
# /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   res_quad2b=scipy.integrate.quad(lambda u, p=p: p*integrand_middle(p,u), 0, delta, limit=npts, epsabs=epsabs, epsrel=epsrel)
# /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   res_quad2a=scipy.integrate.quad(vec_integrand, pmin, p, limit=npts, epsabs=epsabs, epsrel=epsrel)
# Text(0.5, 1.0, 'Experimental observations')

# %%
parameter_space = ParameterSpace([ContinuousParameter('alpha_s', 0.05,0.5 ),
                                  ContinuousParameter('exponent_inel', -3, 3),
                                  ContinuousParameter('exponent_el', -3, 3),
                                  ContinuousParameter('scale_inel', 0.1, 0.5),
                                  ContinuousParameter('scale_el', 0.1, 0.5)])

# %%
from emukit.core.initial_designs import RandomDesign

design = RandomDesign(parameter_space)
num_data_points = 5
X = design.get_samples(num_data_points)
print(f'Shape of X {X.shape}')
# Out:
# Shape of X (5, 5)

# %%
def f(design, pT=pT_obs[0]):
    """returns simulation output for a design matrix"""
    print(design)
    observables=simulation(design,*pT_range)
    #Let's just return only one obsrvable for now. The middle p_T bin
    return observables[:,pT]

def f1(design, pT=pT_obs[0]):
    """returns simulation output for a design matrix"""
    print(design)
    observables=simulation(design,*pT_range)
    #Let's just return only one obsrvable for now. The middle p_T bin
    return observables[:,pT].reshape(-1,1)

def f2(design, pT=pT_obs[1]):
    """returns simulation output for a design matrix"""
    print(design)
    observables=simulation(design,*pT_range)
    #Let's just return only one obsrvable for now. The middle p_T bin
    return observables[:,pT].reshape(-1,1)

def f3(design, pT=pT_obs[2]):
    """returns simulation output for a design matrix"""
    print(design)
    observables=simulation(design,*pT_range)
    #Let's just return only one obsrvable for now. The middle p_T bin
    return observables[:,pT].reshape(-1,1)

fun=np.array([f1, f2, f3])

# %%
#Generate 5 randome observables
Y = f(X,pT_obs)
# Out:
# [[ 0.12020839  1.24843547 -1.9090502   0.21649166  0.28242799]
#  [ 0.12019753 -2.87649303 -1.89957294  0.34474116  0.41407038]
#  [ 0.07613763  2.81945911 -1.17454654  0.15579754  0.17986951]
#  [ 0.43977927  1.99465584  0.14853859  0.21685786  0.30569378]
#  [ 0.32050176 -1.72596534 -0.40832989  0.24654474  0.33696583]]
# Working on 1/5 design
# Working on 2/5 design
# Working on 3/5 design
# Working on 4/5 design
# Working on 5/5 design
# /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:42: RuntimeWarning: invalid value encountered in log
#   log_P_g_prev=np.log(P_g)
# /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   res_quad2c=scipy.integrate.quad(vec_integrand, p, pmax, limit=npts, epsabs=epsabs, epsrel=epsrel)
# /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:79: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   res_quad2c=scipy.integrate.quad(vec_integrand, p*(1+delta), pmax, limit=npts, epsabs=epsabs, epsrel=epsrel)
# /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   res_quad2b=scipy.integrate.quad(lambda u, p=p: p*integrand_middle(p,u), 0, delta, limit=npts, epsabs=epsabs, epsrel=epsrel)
# /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:77: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   res_quad2a=scipy.integrate.quad(vec_integrand, pmin, p*(1-delta), limit=npts, epsabs=epsabs, epsrel=epsrel)
# /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   res_quad2a=scipy.integrate.quad(vec_integrand, pmin, p, limit=npts, epsabs=epsabs, epsrel=epsrel)
# /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   res_quad2c=scipy.integrate.quad(vec_integrand, p, pmax, limit=npts, epsabs=epsabs, epsrel=epsrel)

# %%
from GPy.kern import RBF, White
from GPy.models import GPRegression
from emukit.model_wrappers import GPyModelWrapper
from multiprocessing import Pool

# %% [markdown]
# ### Let's build a emulator for each observable (3 in total) and query 5 points for each emulator at a time. Then train all 3 emulators on these new 5 points that we get in each iteration.

# %%
# size of possible variation of parameters
ptp = np.array([prior_ranges['alpha_s'][1],prior_ranges['exponent_inel'][1],prior_ranges['exponent_el'][1],prior_ranges['scale_inel'][1],prior_ranges['scale_el'][1]])\
-np.array([prior_ranges['alpha_s'][0],prior_ranges['exponent_inel'][0],prior_ranges['exponent_el'][0],prior_ranges['scale_inel'][0],prior_ranges['scale_el'][0]])

gp_array = []
for i,pt in enumerate(pT_obs):
    rbf_kern =      RBF(  input_dim=5,
                          variance= 1,
                          lengthscale=ptp,
                          ARD=True)
    my_kernel = rbf_kern
    model_gpy = GPRegression(X=X,Y=Y[:, i].reshape(-1,1),kernel=my_kernel, noise_var=0.01**2)
    model_gpy.optimize_restarts(num_restarts = 20)
    model_emukit = GPyModelWrapper(model_gpy, n_restarts=20)
    gp_array.append(model_emukit)
# Out:
# Optimization restart 1/20, f = -0.517570421816393
# Optimization restart 2/20, f = -0.5175747604149712
# Optimization restart 3/20, f = -0.5175746063830977
# Optimization restart 4/20, f = 0.2116361865511216
# Optimization restart 5/20, f = 3.7854579870774465
# Optimization restart 6/20, f = -0.5175580628978849
# Optimization restart 7/20, f = -0.5175747161419957
# Optimization restart 8/20, f = -0.5175747258556558
# Optimization restart 9/20, f = -0.5175646946937569
# Optimization restart 10/20, f = -0.517572795787645
# Optimization restart 11/20, f = -0.5175746838216861
# Optimization restart 12/20, f = 3.785458013298841
# Optimization restart 13/20, f = 3.785457200859773
# Optimization restart 14/20, f = -0.5175747586068393
# Optimization restart 15/20, f = 0.2439208648515816
# Optimization restart 16/20, f = -0.5175747629383332
# Optimization restart 17/20, f = -0.5175747704436229
# Optimization restart 18/20, f = 0.09529531154006454
# Optimization restart 19/20, f = 0.24392091118951997
# Optimization restart 20/20, f = -0.5175558135555653
# Optimization restart 1/20, f = -0.46611975331687905
# Optimization restart 2/20, f = -0.1406157803979382
# Optimization restart 3/20, f = -0.46612010112663427
# Optimization restart 4/20, f = -0.14061608941956472
# Optimization restart 5/20, f = -0.46608584091188066
# Optimization restart 6/20, f = -0.4661199102763738
# Optimization restart 7/20, f = -0.4661198600623089
# Optimization restart 8/20, f = -0.4661199720030065
# Optimization restart 9/20, f = -0.46612013042532574
# Optimization restart 10/20, f = -0.46612012242515277
# Optimization restart 11/20, f = 3.497768144883805
# Optimization restart 12/20, f = -0.14061605337975447
# Optimization restart 13/20, f = 3.4976398501580586
# Optimization restart 14/20, f = -0.46608417942037095
# Optimization restart 15/20, f = -0.46611891674571915
# Optimization restart 16/20, f = -0.14061573179169518
# Optimization restart 17/20, f = 3.497768410158757
# Optimization restart 18/20, f = -0.4661201308824965
# Optimization restart 19/20, f = -0.4661201331675269
# Optimization restart 20/20, f = -0.14061609997638147
# Optimization restart 1/20, f = -0.44678043874928175
# Optimization restart 2/20, f = -0.44678042262863915
# Optimization restart 3/20, f = 3.405095421711022
# Optimization restart 4/20, f = -0.44675176660333493
# Optimization restart 5/20, f = 3.2074099720403075
# Optimization restart 6/20, f = -0.24963687151599911
# Optimization restart 7/20, f = -0.4467803358232665
# Optimization restart 8/20, f = -0.44678009721124523
# Optimization restart 9/20, f = 3.405094245839908
# Optimization restart 10/20, f = -0.44675556493532076
# Optimization restart 11/20, f = -0.4467804280305123
# Optimization restart 12/20, f = -0.446780476698041
# Optimization restart 13/20, f = 3.405095070768862
# Optimization restart 14/20, f = -0.4467804801418538
# Optimization restart 15/20, f = -0.24963673580090928
# Optimization restart 16/20, f = 3.4051421919820664
# Optimization restart 17/20, f = -0.4467804149374026
# Optimization restart 18/20, f = -0.4467804421329249
# Optimization restart 19/20, f = -0.24963675881912106
# Optimization restart 20/20, f = -0.4467804239809485

# %%
from emukit.experimental_design.acquisitions import IntegratedVarianceReduction, ModelVariance
from emukit.experimental_design import ExperimentalDesignLoop

# %%
integrated_var = []
for g in gp_array:
    print(g.model)
    #integrated_var.append(IntegratedVarianceReduction(model = g, space=parameter_space))
    integrated_var.append( ModelVariance(model = g))
# Out:
# Name : GP regression
# Objective : -0.5175747704436229
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.26437635834107004  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
#
# Name : GP regression
# Objective : -0.4661201331675269
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |       0.250101844615355  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
#
# Name : GP regression
# Objective : -0.4467804801418538
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |      0.2426256656722259  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |

# %%
#from emukit.core.optimization import GradientAcquisitionOptimizer
#optimizer = GradientAcquisitionOptimizer(parameter_space)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (5, 5)
# (5, 3)

# %%
import time
outer_loop_st = time.time()
for i in range(0,10):
#model_variance = ModelVariance(model = model_emukit)
    gp = i%3
    print (f'Trainng {gp} gp for R_AA at {pT_obs[gp]} GeV')
    integrated_var = IntegratedVarianceReduction(model = gp_array[gp], space=parameter_space)
    expdesign_loop = ExperimentalDesignLoop(model = gp_array[gp],
                                         space = parameter_space,
                                         acquisition = integrated_var,
                                         batch_size = 10)
    ed=expdesign_loop.run_loop(fun[gp],1)
    X_latest=gp_array[gp].X[-10:,:]
    Y_latest= f(X_latest, pT=pT_obs)         
    for k in range(0,3):
        if k!=gp:
            X = np.append(gp_array[k].X, X_latest, axis=0)
            
            Y = np.append(gp_array[k].Y, Y_latest[:,k].reshape(-1,1), axis=0)
            print(X.shape)
            print(Y.shape)
            gp_array[k].set_data(X, Y)
            print(f'Optimizing the GP {k}')
            print('\n before optimization')
            print(gp_array[k].model)
            st = time.time()
            gp_array[k].optimize()
            et = time.time()
            print(f'Time it takes to do optimization {et-st}')
            print('\n after optimization')
            print(gp_array[k].model)
print(f'Total time for this cell {outer_loop_st-time.time()} S')
# Out:
# Trainng 0 gp for R_AA at 3 GeV
# Optimization restart 1/20, f = -0.5175747706933396
# Optimization restart 2/20, f = -0.5175662286444762
# Optimization restart 3/20, f = 3.785458013174696
# Optimization restart 4/20, f = -0.5175543957440323
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/paramz/transformations.py:111: RuntimeWarning:overflow encountered in expm1
# Optimization restart 5/20, f = -0.5175728793023517
# Optimization restart 6/20, f = -0.517574623468966
# Optimization restart 7/20, f = -0.5175740282010093
# Optimization restart 8/20, f = 0.09529536028016183
# Optimization restart 9/20, f = 0.09529531429182114
# Optimization restart 10/20, f = -0.5175747730426759
# Optimization restart 11/20, f = -0.517574368985922
# Optimization restart 12/20, f = -0.517574764724869
# Optimization restart 13/20, f = 0.21163621765692886
# Optimization restart 14/20, f = 0.24394804332098818
# Optimization restart 15/20, f = -0.5175741700470251
# Optimization restart 16/20, f = 0.21163620987003595
# Optimization restart 17/20, f = -0.517574735683723
# Optimization restart 18/20, f = 3.7854579597096176
# Optimization restart 19/20, f = -0.5175747804582751
# Optimization restart 20/20, f = -0.5175747420623544
# [[ 0.46525569 -0.8468493  -2.08322977  0.18277249  0.45059167]
#  [ 0.23241992  2.20988374  1.58607441  0.3637311   0.36880972]
#  [ 0.33286407 -1.03836672 -1.09700038  0.10074547  0.20514799]
#  [ 0.16528342  1.36196782 -0.68266914  0.38436382  0.48416958]
#  [ 0.42185033 -2.57304169  0.78631262  0.38318063  0.18198774]
#  [ 0.19633615 -0.32837269  0.6690781   0.31991864  0.23098024]
#  [ 0.09205646 -2.69725068 -1.02777201  0.38995976  0.13578621]
#  [ 0.27457818  0.28022995  2.35585323  0.30330716  0.33556859]
#  [ 0.42187287  0.61268324  0.66153411  0.19625072  0.10964477]
#  [ 0.4190755   2.10999318 -1.185292    0.22953672  0.16440864]]
# Working on 1/10 design
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning:dopri5: step size becomes too small
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning:dopri5: larger nsteps is needed
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:42: RuntimeWarning:invalid value encountered in log
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:79: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:77: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
# For model parameters [ 0.46525569 -0.8468493  -2.08322977  0.18277249  0.45059167] takes 113.72585868835449 S
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# For model parameters [ 0.42185033 -2.57304169  0.78631262  0.38318063  0.18198774] takes 203.24713277816772 S
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# Optimization restart 1/20, f = -9.004703453054137
# Optimization restart 2/20, f = -16.993516871645603
# Optimization restart 3/20, f = -17.094627302936225
# Optimization restart 4/20, f = -16.993516877374944
# Optimization restart 5/20, f = -16.993516876836015
# Optimization restart 6/20, f = -16.99351731357698
# Optimization restart 7/20, f = -17.094627301428797
# Optimization restart 8/20, f = -16.993516873304877
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/GPy/kern/src/stationary.py:243: RuntimeWarning:invalid value encountered in true_divide
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/GPy/kern/src/stationary.py:137: RuntimeWarning:overflow encountered in square
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/GPy/kern/src/stationary.py:138: RuntimeWarning:invalid value encountered in add
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/GPy/kern/src/rbf.py:76: RuntimeWarning:invalid value encountered in multiply
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/GPy/kern/src/stationary.py:166: RuntimeWarning:overflow encountered in true_divide
# Optimization restart 9/20, f = -16.929870923777766
# Optimization restart 10/20, f = -16.57624027939072
# Optimization restart 11/20, f = -17.094627303820698
# Optimization restart 12/20, f = -17.094627265807507
# Optimization restart 13/20, f = -17.094627298407282
# Optimization restart 14/20, f = -17.094627302994592
# Optimization restart 15/20, f = -16.993516877436875
# Optimization restart 16/20, f = -16.99351687696215
# Optimization restart 17/20, f = -17.094627293549642
# Optimization restart 18/20, f = -17.09462730358613
# Optimization restart 19/20, f = -17.09462730385073
# Optimization restart 20/20, f = -16.993527363432122
# [[ 0.46525569 -0.8468493  -2.08322977  0.18277249  0.45059167]
#  [ 0.23241992  2.20988374  1.58607441  0.3637311   0.36880972]
#  [ 0.33286407 -1.03836672 -1.09700038  0.10074547  0.20514799]
#  [ 0.16528342  1.36196782 -0.68266914  0.38436382  0.48416958]
#  [ 0.42185033 -2.57304169  0.78631262  0.38318063  0.18198774]
#  [ 0.19633615 -0.32837269  0.6690781   0.31991864  0.23098024]
#  [ 0.09205646 -2.69725068 -1.02777201  0.38995976  0.13578621]
#  [ 0.27457818  0.28022995  2.35585323  0.30330716  0.33556859]
#  [ 0.42187287  0.61268324  0.66153411  0.19625072  0.10964477]
#  [ 0.4190755   2.10999318 -1.185292    0.22953672  0.16440864]]
# Working on 1/10 design
# For model parameters [ 0.46525569 -0.8468493  -2.08322977  0.18277249  0.45059167] takes 109.70280408859253 S
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# For model parameters [ 0.42185033 -2.57304169  0.78631262  0.38318063  0.18198774] takes 210.0071771144867 S
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# (15, 5)
# (15, 1)
# Optimizing the GP 1
#
#  before optimization
#
# Name : GP regression
# Objective : 1529.2345994810298
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |       0.250101844615355  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Optimization restart 1/20, f = -10.962536715312268
# Optimization restart 2/20, f = -18.24446441068486
# Optimization restart 3/20, f = -18.24446471588388
# Optimization restart 4/20, f = -18.24446477565874
# Optimization restart 5/20, f = 6.150354975783673
# Optimization restart 6/20, f = 6.150092147003785
# Optimization restart 7/20, f = -18.24446469220895
# Optimization restart 8/20, f = -18.244464717257703
# Optimization restart 9/20, f = -18.244464523018063
# Optimization restart 10/20, f = -18.24446427424342
# Optimization restart 11/20, f = -16.536010032234092
# Optimization restart 12/20, f = -18.24446480761772
# Optimization restart 13/20, f = -5.132060575037042
# Optimization restart 14/20, f = -16.536010103994627
# Optimization restart 15/20, f = -18.244464655766055
# Optimization restart 16/20, f = -18.244464626140353
# Optimization restart 17/20, f = -18.244464748156943
# Optimization restart 18/20, f = -18.244464735363334
# Optimization restart 19/20, f = -18.244161808668853
# Optimization restart 20/20, f = -18.243678805907646
# Time it takes to do optimization 1.7586190700531006
#
#  after optimization
#
# Name : GP regression
# Objective : -18.24446480761772
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                    value  |  constraints  |  priors
#   rbf.variance             |      0.19091402639176305  |      +ve      |
#   rbf.lengthscale          |                     (5,)  |      +ve      |
#   Gaussian_noise.variance  |  2.0220081468041905e-219  |      +ve      |
# (15, 5)
# (15, 1)
# Optimizing the GP 2
#
#  before optimization
#
# Name : GP regression
# Objective : 1081.464679286176
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |      0.2426256656722259  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Optimization restart 1/20, f = -11.681845198549443
# Optimization restart 2/20, f = -17.93277380572257
# Optimization restart 3/20, f = -17.93277389853879
# Optimization restart 4/20, f = -17.932773924428197
# Optimization restart 5/20, f = -17.932773781365984
# Optimization restart 6/20, f = -16.69765230555757
# Optimization restart 7/20, f = -17.932773867412774
# Optimization restart 8/20, f = -17.932773946965284
# Optimization restart 9/20, f = -17.93224528934462
# Optimization restart 10/20, f = -17.932772551503476
# Optimization restart 11/20, f = -17.93277348404415
# Optimization restart 12/20, f = -17.932773982777867
# Optimization restart 13/20, f = -16.77160231729681
# Optimization restart 14/20, f = -17.932773993857946
# Optimization restart 15/20, f = -16.69765230562714
# Optimization restart 16/20, f = 5.683827257333146
# Optimization restart 17/20, f = -17.932773928606423
# Optimization restart 18/20, f = -17.932773943861832
# Optimization restart 19/20, f = -17.932773969026155
# Optimization restart 20/20, f = -17.932773590170406
# Time it takes to do optimization 1.916290044784546
#
#  after optimization
#
# Name : GP regression
# Objective : -17.932773993857946
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.16642891968227153  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Trainng 1 gp for R_AA at 5 GeV
# Optimization restart 1/20, f = -18.244464807759226
# Optimization restart 2/20, f = -18.244464661493165
# Optimization restart 3/20, f = -18.244464651109894
# Optimization restart 4/20, f = -18.244464293464922
# Optimization restart 5/20, f = -18.244464777639855
# Optimization restart 6/20, f = -18.2444641572152
# Optimization restart 7/20, f = -18.243479232080446
# Optimization restart 8/20, f = -18.24446480979491
# Optimization restart 9/20, f = -18.244464762866016
# Optimization restart 10/20, f = -18.244464797507902
# Optimization restart 11/20, f = -18.244464805769457
# Optimization restart 12/20, f = -18.2444638292573
# Optimization restart 13/20, f = -18.244464807107207
# Optimization restart 14/20, f = -16.536010184423453
# Optimization restart 15/20, f = -18.244464607383428
# Optimization restart 16/20, f = -18.244461994508878
# Optimization restart 17/20, f = -18.244464556848776
# Optimization restart 18/20, f = -18.244464772735565
# Optimization restart 19/20, f = -18.244464614531235
# Optimization restart 20/20, f = -18.244464692078513
# [[ 0.09337452  0.55148802  0.23841159  0.13188214  0.34677882]
#  [ 0.45217855 -0.11026535 -0.62803821  0.41057889  0.14320267]
#  [ 0.27297805  1.23969133 -1.06980361  0.32782041  0.46713746]
#  [ 0.19067741 -2.14780793  2.65062169  0.35628187  0.22408461]
#  [ 0.41232273 -1.55844877  2.83930379  0.13404355  0.3494889 ]
#  [ 0.20945623 -1.57883201 -0.59877583  0.24996159  0.21645829]
#  [ 0.28795928 -0.03753222  2.37402767  0.2531016   0.4849681 ]
#  [ 0.12755571  1.80446272  2.10563912  0.19823665  0.32844042]
#  [ 0.20050903  1.53770545 -0.82476692  0.2218372   0.20299854]
#  [ 0.47408716 -2.63981582 -1.45869714  0.42989235  0.39888474]]
# Working on 1/10 design
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# For model parameters [ 0.47408716 -2.63981582 -1.45869714  0.42989235  0.39888474] takes 436.3134469985962 S
# Optimization restart 1/20, f = -28.05250791004137
# Optimization restart 2/20, f = -28.40648628552875
# Optimization restart 3/20, f = -28.406597796482096
# Optimization restart 4/20, f = -27.456239944764693
# Optimization restart 5/20, f = -28.284009900848673
# Optimization restart 6/20, f = -28.28400987481439
# Optimization restart 7/20, f = -28.40659742089748
# Optimization restart 8/20, f = -28.4065976453858
# Optimization restart 9/20, f = -28.28400928266635
# Optimization restart 10/20, f = -27.456239991160786
# Optimization restart 11/20, f = -27.456239677889947
# Optimization restart 12/20, f = -27.45623824544745
# Optimization restart 13/20, f = -28.284007270475385
# Optimization restart 14/20, f = -28.4065387668617
# Optimization restart 15/20, f = -28.406597736438076
# Optimization restart 16/20, f = -28.406538971322334
# Optimization restart 17/20, f = -27.45623978426849
# Optimization restart 18/20, f = -28.2840093370077
# Optimization restart 19/20, f = -28.284008243090433
# Optimization restart 20/20, f = -28.406593551283745
# [[ 0.09337452  0.55148802  0.23841159  0.13188214  0.34677882]
#  [ 0.45217855 -0.11026535 -0.62803821  0.41057889  0.14320267]
#  [ 0.27297805  1.23969133 -1.06980361  0.32782041  0.46713746]
#  [ 0.19067741 -2.14780793  2.65062169  0.35628187  0.22408461]
#  [ 0.41232273 -1.55844877  2.83930379  0.13404355  0.3494889 ]
#  [ 0.20945623 -1.57883201 -0.59877583  0.24996159  0.21645829]
#  [ 0.28795928 -0.03753222  2.37402767  0.2531016   0.4849681 ]
#  [ 0.12755571  1.80446272  2.10563912  0.19823665  0.32844042]
#  [ 0.20050903  1.53770545 -0.82476692  0.2218372   0.20299854]
#  [ 0.47408716 -2.63981582 -1.45869714  0.42989235  0.39888474]]
# Working on 1/10 design
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# For model parameters [ 0.47408716 -2.63981582 -1.45869714  0.42989235  0.39888474] takes 464.30871987342834 S
# (25, 5)
# (25, 1)
# Optimizing the GP 0
#
#  before optimization
#
# Name : GP regression
# Objective : 111.08900172318558
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |       0.225223212651827  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  4.1030228405283814e-05  |      +ve      |
# Optimization restart 1/20, f = -27.287502114501986
# Optimization restart 2/20, f = -27.287507158561084
# Optimization restart 3/20, f = -27.287507060668503
# Optimization restart 4/20, f = -27.28750663863268
# Optimization restart 5/20, f = -27.287506656823076
# Optimization restart 6/20, f = -27.287498492833134
# Optimization restart 7/20, f = -27.287506821138354
# Optimization restart 8/20, f = -27.287504622979466
# Optimization restart 9/20, f = -27.2875049497414
# Optimization restart 10/20, f = -27.287506242892142
# Optimization restart 11/20, f = -27.28750655524243
# Optimization restart 12/20, f = -25.536489994061974
# Optimization restart 13/20, f = -27.287506767240046
# Optimization restart 14/20, f = -27.287504048992517
# Optimization restart 15/20, f = -27.287506303144667
# Optimization restart 16/20, f = -27.2875067801021
# Optimization restart 17/20, f = -27.287506296515126
# Optimization restart 18/20, f = -27.287505122808142
# Optimization restart 19/20, f = -25.53648978319863
# Optimization restart 20/20, f = -27.28750675598254
# Time it takes to do optimization 2.3470020294189453
#
#  after optimization
#
# Name : GP regression
# Objective : -27.287507158561084
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.21753847679622887  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.0018359800350033454  |      +ve      |
# (25, 5)
# (25, 1)
# Optimizing the GP 2
#
#  before optimization
#
# Name : GP regression
# Objective : 121.15646391138424
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.16642891968227153  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Optimization restart 1/20, f = -28.666481197060268
# Optimization restart 2/20, f = -28.54056910549427
# Optimization restart 3/20, f = -28.825384794651725
# Optimization restart 4/20, f = -28.825443498665656
# Optimization restart 5/20, f = -28.825440647957365
# Optimization restart 6/20, f = -27.83596093741599
# Optimization restart 7/20, f = -27.835961431092223
# Optimization restart 8/20, f = -27.835961660550772
# Optimization restart 9/20, f = -28.82543315363445
# Optimization restart 10/20, f = -28.82544444386059
# Optimization restart 11/20, f = -28.54056922424844
# Optimization restart 12/20, f = -28.540568891934193
# Optimization restart 13/20, f = -27.835961629684192
# Optimization restart 14/20, f = -28.825444549464095
# Optimization restart 15/20, f = -27.83596152308547
# Optimization restart 16/20, f = -27.847113809065014
# Optimization restart 17/20, f = -28.825248696605485
# Optimization restart 18/20, f = -28.540563353196024
# Optimization restart 19/20, f = -28.54056848828475
# Optimization restart 20/20, f = -28.825430399722304
# Time it takes to do optimization 2.2237741947174072
#
#  after optimization
#
# Name : GP regression
# Objective : -28.825444549464095
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.28855796538525524  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  1.761245647836875e-11  |      +ve      |
# Trainng 2 gp for R_AA at 7 GeV
# Optimization restart 1/20, f = -28.825444567932962
# Optimization restart 2/20, f = -28.825444629586457
# Optimization restart 3/20, f = -27.847112876664724
# Optimization restart 4/20, f = -28.82512449250857
# Optimization restart 5/20, f = -28.825404365779264
# Optimization restart 6/20, f = -28.825444673814484
# Optimization restart 7/20, f = -27.83596148198596
# Optimization restart 8/20, f = -28.540569130715408
# Optimization restart 9/20, f = -28.540567222790138
# Optimization restart 10/20, f = -27.83596142296544
# Optimization restart 11/20, f = -28.82542604370451
# Optimization restart 12/20, f = -28.82544457162242
# Optimization restart 13/20, f = -28.825444466388014
# Optimization restart 14/20, f = -27.83596156547264
# Optimization restart 15/20, f = -28.825432463001615
# Optimization restart 16/20, f = -28.540568632728494
# Optimization restart 17/20, f = -27.847113918378042
# Optimization restart 18/20, f = -28.825433332224694
# Optimization restart 19/20, f = -28.825430895691255
# Optimization restart 20/20, f = -28.825443356254873
# [[ 0.08077252 -2.04147124  0.01602192  0.31613945  0.31841754]
#  [ 0.40298816  2.64351747  1.93474261  0.24595321  0.13526319]
#  [ 0.28225633  2.80011247 -1.77157079  0.37413285  0.43615449]
#  [ 0.37820567 -2.6293397   2.22518645  0.3358664   0.26199799]
#  [ 0.29923421  1.13773904 -1.33241593  0.42455448  0.42579176]
#  [ 0.32644264 -2.52535784 -2.79247935  0.23297076  0.25855025]
#  [ 0.2636365   0.16673709 -2.23687571  0.33931919  0.44823028]
#  [ 0.09521631 -1.73043548 -1.80235436  0.31624973  0.38718216]
#  [ 0.46772357  2.45653569 -0.85627096  0.24641402  0.27703029]
#  [ 0.42275616  2.35654832 -0.55005296  0.24152293  0.35758027]]
# Working on 1/10 design
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# For model parameters [ 0.37820567 -2.6293397   2.22518645  0.3358664   0.26199799] takes 115.97139692306519 S
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# Optimization restart 1/20, f = -29.639013107231378
# Optimization restart 2/20, f = -35.60405304966186
# Optimization restart 3/20, f = -35.605207410562
# Optimization restart 4/20, f = -39.840462946368305
# Optimization restart 5/20, f = -35.60237363619062
# Optimization restart 6/20, f = -35.6032991366378
# Optimization restart 7/20, f = -35.60544345805582
# Optimization restart 8/20, f = -35.605161271330985
# Optimization restart 9/20, f = -35.605476644755086
# Optimization restart 10/20, f = -35.60488666141046
# Optimization restart 11/20, f = -35.60399028775546
# Optimization restart 12/20, f = -35.60135180688228
# Optimization restart 13/20, f = -35.605209053221586
# Optimization restart 14/20, f = -39.84046394121233
# Optimization restart 15/20, f = -39.84046439995162
# Optimization restart 16/20, f = -35.60555716124764
# Optimization restart 17/20, f = -35.60526034237398
# Optimization restart 18/20, f = -39.84045967295326
# Optimization restart 19/20, f = -35.60529775147569
# Optimization restart 20/20, f = -39.840464461192624
# [[ 0.08077252 -2.04147124  0.01602192  0.31613945  0.31841754]
#  [ 0.40298816  2.64351747  1.93474261  0.24595321  0.13526319]
#  [ 0.28225633  2.80011247 -1.77157079  0.37413285  0.43615449]
#  [ 0.37820567 -2.6293397   2.22518645  0.3358664   0.26199799]
#  [ 0.29923421  1.13773904 -1.33241593  0.42455448  0.42579176]
#  [ 0.32644264 -2.52535784 -2.79247935  0.23297076  0.25855025]
#  [ 0.2636365   0.16673709 -2.23687571  0.33931919  0.44823028]
#  [ 0.09521631 -1.73043548 -1.80235436  0.31624973  0.38718216]
#  [ 0.46772357  2.45653569 -0.85627096  0.24641402  0.27703029]
#  [ 0.42275616  2.35654832 -0.55005296  0.24152293  0.35758027]]
# Working on 1/10 design
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# For model parameters [ 0.37820567 -2.6293397   2.22518645  0.3358664   0.26199799] takes 117.34056305885315 S
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# (35, 5)
# (35, 1)
# Optimizing the GP 0
#
#  before optimization
#
# Name : GP regression
# Objective : -28.731594293467946
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.21753847679622887  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.0018359800350033454  |      +ve      |
# Optimization restart 1/20, f = -32.71122075782522
# Optimization restart 2/20, f = -33.75100190954727
# Optimization restart 3/20, f = -33.75099997882175
# Optimization restart 4/20, f = -33.75100185620099
# Optimization restart 5/20, f = -33.75100188816836
# Optimization restart 6/20, f = -37.368908681709556
# Optimization restart 7/20, f = -36.35415314960707
# Optimization restart 8/20, f = -33.75100178494953
# Optimization restart 9/20, f = -33.75100089546626
# Optimization restart 10/20, f = -33.751001745859625
# Optimization restart 11/20, f = -37.36890861344256
# Optimization restart 12/20, f = -33.751000922194656
# Optimization restart 13/20, f = -33.751002002070074
# Optimization restart 14/20, f = -33.75100167475397
# Optimization restart 15/20, f = -36.35415269076684
# Optimization restart 16/20, f = -37.368903773322096
# Optimization restart 17/20, f = -36.35415289396167
# Optimization restart 18/20, f = -36.354152966241884
# Optimization restart 19/20, f = -36.35415296406863
# Optimization restart 20/20, f = -36.35415322113374
# Time it takes to do optimization 2.5057969093322754
#
#  after optimization
#
# Name : GP regression
# Objective : -37.368908681709556
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.15473375042933576  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# (35, 5)
# (35, 1)
# Optimizing the GP 1
#
#  before optimization
#
# Name : GP regression
# Objective : 72.76494828305171
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.29878145117299204  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  2.147092804916251e-11  |      +ve      |
# Optimization restart 1/20, f = -29.35794397641638
# Optimization restart 2/20, f = -34.97736717330319
# Optimization restart 3/20, f = -34.97816850774447
# Optimization restart 4/20, f = -39.22444248236957
# Optimization restart 5/20, f = -34.977984937426434
# Optimization restart 6/20, f = -34.97630461030476
# Optimization restart 7/20, f = -34.97818359123512
# Optimization restart 8/20, f = -34.98376654078844
# Optimization restart 9/20, f = -39.22444276615205
# Optimization restart 10/20, f = -34.97756410272471
# Optimization restart 11/20, f = -34.978176524561974
# Optimization restart 12/20, f = -34.97669738084022
# Optimization restart 13/20, f = -34.97820391314452
# Optimization restart 14/20, f = -34.97755609564912
# Optimization restart 15/20, f = -39.22444208636642
# Optimization restart 16/20, f = -34.977568094251524
# Optimization restart 17/20, f = -35.74941708127763
# Optimization restart 18/20, f = -34.97723853461446
# Optimization restart 19/20, f = -39.22444277965677
# Optimization restart 20/20, f = -39.22444295615287
# Time it takes to do optimization 1.9406929016113281
#
#  after optimization
#
# Name : GP regression
# Objective : -39.22444295615287
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.18024109378640565  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Trainng 0 gp for R_AA at 3 GeV
# Optimization restart 1/20, f = -37.36890868364678
# Optimization restart 2/20, f = -37.36890850115083
# Optimization restart 3/20, f = -36.354153016180845
# Optimization restart 4/20, f = -33.75100195800697
# Optimization restart 5/20, f = -7.133755987422738
# Optimization restart 6/20, f = -33.61596056964848
# Optimization restart 7/20, f = -33.4877723183494
# Optimization restart 8/20, f = -36.35415304675237
# Optimization restart 9/20, f = -33.751001976658344
# Optimization restart 10/20, f = -36.35415333032135
# Optimization restart 11/20, f = -33.75100182619008
# Optimization restart 12/20, f = -33.751001419583176
# Optimization restart 13/20, f = -36.354153348599894
# Optimization restart 14/20, f = -36.354153067901095
# Optimization restart 15/20, f = -33.751001938656174
# Optimization restart 16/20, f = -36.35415325823112
# Optimization restart 17/20, f = -33.75100171305649
# Optimization restart 18/20, f = -37.368907301118455
# Optimization restart 19/20, f = -33.751001908309945
# Optimization restart 20/20, f = -33.75100186909981
# [[ 0.06061697  0.5397425   1.55277125  0.41902181  0.38135184]
#  [ 0.43646571  1.86070593  0.75064341  0.39247661  0.38509903]
#  [ 0.28814543 -2.19521588  0.46549883  0.47893475  0.12998248]
#  [ 0.44147668 -0.82792801  2.30873746  0.39001039  0.12054136]
#  [ 0.10613424  2.54819213  1.97805048  0.3960149   0.13961831]
#  [ 0.48272567 -2.4454251  -0.07006873  0.26096455  0.28280087]
#  [ 0.19200047 -2.36892795  1.55533066  0.16804783  0.47319713]
#  [ 0.0835662   2.16479674 -1.26939436  0.40968442  0.20978248]
#  [ 0.11906431 -1.42118675 -2.08585109  0.3730793   0.24351302]
#  [ 0.38386006  0.18619242  1.31523329  0.36364537  0.30900343]]
# Working on 1/10 design
# Working on 2/10 design
# Working on 3/10 design
# For model parameters [ 0.28814543 -2.19521588  0.46549883  0.47893475  0.12998248] takes 131.47160696983337 S
# Working on 4/10 design
# For model parameters [ 0.44147668 -0.82792801  2.30873746  0.39001039  0.12054136] takes 94.1933970451355 S
# Working on 5/10 design
# Working on 6/10 design
# For model parameters [ 0.48272567 -2.4454251  -0.07006873  0.26096455  0.28280087] takes 115.2220458984375 S
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# Optimization restart 1/20, f = -49.324831985777436
# Optimization restart 2/20, f = -49.32483193960756
# Optimization restart 3/20, f = -49.324831498200496
# Optimization restart 4/20, f = -49.32483124345488
# Optimization restart 5/20, f = -49.324831756229926
# Optimization restart 6/20, f = -49.32483162432355
# Optimization restart 7/20, f = -49.324831658792476
# Optimization restart 8/20, f = -49.324828327925175
# Optimization restart 9/20, f = -49.324831903924675
# Optimization restart 10/20, f = -49.324831438664276
# Optimization restart 11/20, f = -49.3248312308213
# Optimization restart 12/20, f = -49.324831417787294
# Optimization restart 13/20, f = -49.32483188135014
# Optimization restart 14/20, f = -49.32483161264555
# Optimization restart 15/20, f = -49.32483148334106
# Optimization restart 16/20, f = -49.32483175991807
# Optimization restart 17/20, f = -49.32482974185319
# Optimization restart 18/20, f = -49.3248315728782
# Optimization restart 19/20, f = -49.32483146926379
# Optimization restart 20/20, f = -49.324831106255346
# [[ 0.06061697  0.5397425   1.55277125  0.41902181  0.38135184]
#  [ 0.43646571  1.86070593  0.75064341  0.39247661  0.38509903]
#  [ 0.28814543 -2.19521588  0.46549883  0.47893475  0.12998248]
#  [ 0.44147668 -0.82792801  2.30873746  0.39001039  0.12054136]
#  [ 0.10613424  2.54819213  1.97805048  0.3960149   0.13961831]
#  [ 0.48272567 -2.4454251  -0.07006873  0.26096455  0.28280087]
#  [ 0.19200047 -2.36892795  1.55533066  0.16804783  0.47319713]
#  [ 0.0835662   2.16479674 -1.26939436  0.40968442  0.20978248]
#  [ 0.11906431 -1.42118675 -2.08585109  0.3730793   0.24351302]
#  [ 0.38386006  0.18619242  1.31523329  0.36364537  0.30900343]]
# Working on 1/10 design
# Working on 2/10 design
# Working on 3/10 design
# For model parameters [ 0.28814543 -2.19521588  0.46549883  0.47893475  0.12998248] takes 123.20117712020874 S
# Working on 4/10 design
# For model parameters [ 0.44147668 -0.82792801  2.30873746  0.39001039  0.12054136] takes 85.50521492958069 S
# Working on 5/10 design
# Working on 6/10 design
# For model parameters [ 0.48272567 -2.4454251  -0.07006873  0.26096455  0.28280087] takes 111.90473699569702 S
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# (45, 5)
# (45, 1)
# Optimizing the GP 1
#
#  before optimization
#
# Name : GP regression
# Objective : -44.817718106411505
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.18024109378640565  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Optimization restart 1/20, f = -49.67369869021861
# Optimization restart 2/20, f = -49.67369791302758
# Optimization restart 3/20, f = -49.67369667350175
# Optimization restart 4/20, f = -48.108053913697276
# Optimization restart 5/20, f = -48.108054023897026
# Optimization restart 6/20, f = -49.673698557829596
# Optimization restart 7/20, f = -49.67369849681854
# Optimization restart 8/20, f = -49.67369611251375
# Optimization restart 9/20, f = -49.673698434493545
# Optimization restart 10/20, f = -49.673698059912354
# Optimization restart 11/20, f = -48.10805245898143
# Optimization restart 12/20, f = -49.67369851789935
# Optimization restart 13/20, f = -48.10805374793101
# Optimization restart 14/20, f = -49.67369813331875
# Optimization restart 15/20, f = -49.673698252563426
# Optimization restart 16/20, f = -49.673698245626994
# Optimization restart 17/20, f = -49.67369783557977
# Optimization restart 18/20, f = -49.67369830319284
# Optimization restart 19/20, f = -48.108053415102496
# Optimization restart 20/20, f = -49.673696909206214
# Time it takes to do optimization 3.102842092514038
#
#  after optimization
#
# Name : GP regression
# Objective : -49.67369869021861
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.12335978474618707  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# (45, 5)
# (45, 1)
# Optimizing the GP 2
#
#  before optimization
#
# Name : GP regression
# Objective : -44.153115223202704
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |      0.1927424022232245  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Optimization restart 1/20, f = -50.07983122569706
# Optimization restart 2/20, f = -49.48098200105639
# Optimization restart 3/20, f = -49.480981973423624
# Optimization restart 4/20, f = -49.48098151698737
# Optimization restart 5/20, f = -49.48069192645218
# Optimization restart 6/20, f = -50.07982972128248
# Optimization restart 7/20, f = -49.480981312428696
# Optimization restart 8/20, f = -50.07983056052906
# Optimization restart 9/20, f = -50.079831002726735
# Optimization restart 10/20, f = -50.07983092916923
# Optimization restart 11/20, f = -50.07983111435916
# Optimization restart 12/20, f = -49.48098153357235
# Optimization restart 13/20, f = -49.48098191180465
# Optimization restart 14/20, f = -49.480981720087236
# Optimization restart 15/20, f = -49.48098153986203
# Optimization restart 16/20, f = -50.07982990896501
# Optimization restart 17/20, f = -49.48097935477746
# Optimization restart 18/20, f = -49.478216907949744
# Optimization restart 19/20, f = -50.07983095630503
# Optimization restart 20/20, f = -49.48098186269259
# Time it takes to do optimization 3.5081286430358887
#
#  after optimization
#
# Name : GP regression
# Objective : -50.07983122569706
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.12116836703720774  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Trainng 1 gp for R_AA at 5 GeV
# Optimization restart 1/20, f = -49.67369869023044
# Optimization restart 2/20, f = -49.67369850684295
# Optimization restart 3/20, f = -49.67369704382354
# Optimization restart 4/20, f = -49.67369795054523
# Optimization restart 5/20, f = -49.67369860470563
# Optimization restart 6/20, f = -49.673696345854154
# Optimization restart 7/20, f = -49.67369806496349
# Optimization restart 8/20, f = -48.10805351890758
# Optimization restart 9/20, f = -49.67369842520947
# Optimization restart 10/20, f = -48.10805045279048
# Optimization restart 11/20, f = -49.67369863042806
# Optimization restart 12/20, f = -49.67369856001427
# Optimization restart 13/20, f = -49.67369832812656
# Optimization restart 14/20, f = -49.67369854332186
# Optimization restart 15/20, f = -49.67369842176424
# Optimization restart 16/20, f = -48.10805384784649
# Optimization restart 17/20, f = -49.673698257754936
# Optimization restart 18/20, f = -49.673697585098374
# Optimization restart 19/20, f = -48.1080530441163
# Optimization restart 20/20, f = -49.67369852344835
# [[ 0.35916509  2.61810282 -0.01185359  0.14371721  0.31256101]
#  [ 0.15861209 -0.54895777  1.00629583  0.46244585  0.31306523]
#  [ 0.10007007 -1.8699291  -0.99152428  0.13126299  0.48624037]
#  [ 0.42745581  1.96811127 -0.1006276   0.45095483  0.43164946]
#  [ 0.29025845  2.04104536  0.84982147  0.46379443  0.39528799]
#  [ 0.3644583  -1.35871944 -2.51158239  0.35155476  0.46348924]
#  [ 0.40525383 -2.18799314 -1.63637081  0.20628971  0.43628437]
#  [ 0.08136508  2.00866459  0.77779944  0.26898607  0.3070576 ]
#  [ 0.10310503 -0.36648965  2.59165122  0.21097121  0.39098575]
#  [ 0.43462233 -0.45940033  1.08594074  0.4651878   0.17837956]]
# Working on 1/10 design
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# For model parameters [ 0.3644583  -1.35871944 -2.51158239  0.35155476  0.46348924] takes 147.69286394119263 S
# Working on 7/10 design
# For model parameters [ 0.40525383 -2.18799314 -1.63637081  0.20628971  0.43628437] takes 66.11334300041199 S
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# Optimization restart 1/20, f = -70.12198259780746
# Optimization restart 2/20, f = -70.12198063990789
# Optimization restart 3/20, f = -70.12198218377071
# Optimization restart 4/20, f = -70.1219822498943
# Optimization restart 5/20, f = -70.1219819103511
# Optimization restart 6/20, f = -70.12198050877336
# Optimization restart 7/20, f = -70.12197920062268
# Optimization restart 8/20, f = -70.12198200357949
# Optimization restart 9/20, f = -70.12198195583272
# Optimization restart 10/20, f = -70.12198135105263
# Optimization restart 11/20, f = -70.121982419522
# Optimization restart 12/20, f = -70.12198057785982
# Optimization restart 13/20, f = -70.12198180148374
# Optimization restart 14/20, f = -70.12197912538413
# Optimization restart 15/20, f = -70.1219820627684
# Optimization restart 16/20, f = -70.12198188499995
# Optimization restart 17/20, f = -70.12198168241522
# Optimization restart 18/20, f = -70.12198060373059
# Optimization restart 19/20, f = -70.12198228801905
# Optimization restart 20/20, f = -70.12198205436098
# [[ 0.35916509  2.61810282 -0.01185359  0.14371721  0.31256101]
#  [ 0.15861209 -0.54895777  1.00629583  0.46244585  0.31306523]
#  [ 0.10007007 -1.8699291  -0.99152428  0.13126299  0.48624037]
#  [ 0.42745581  1.96811127 -0.1006276   0.45095483  0.43164946]
#  [ 0.29025845  2.04104536  0.84982147  0.46379443  0.39528799]
#  [ 0.3644583  -1.35871944 -2.51158239  0.35155476  0.46348924]
#  [ 0.40525383 -2.18799314 -1.63637081  0.20628971  0.43628437]
#  [ 0.08136508  2.00866459  0.77779944  0.26898607  0.3070576 ]
#  [ 0.10310503 -0.36648965  2.59165122  0.21097121  0.39098575]
#  [ 0.43462233 -0.45940033  1.08594074  0.4651878   0.17837956]]
# Working on 1/10 design
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# For model parameters [ 0.3644583  -1.35871944 -2.51158239  0.35155476  0.46348924] takes 153.5830159187317 S
# Working on 7/10 design
# For model parameters [ 0.40525383 -2.18799314 -1.63637081  0.20628971  0.43628437] takes 67.22561693191528 S
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# (55, 5)
# (55, 1)
# Optimizing the GP 0
#
#  before optimization
#
# Name : GP regression
# Objective : -64.98686759106866
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.14342836049535435  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Optimization restart 1/20, f = -68.0098489804497
# Optimization restart 2/20, f = -68.00984888725509
# Optimization restart 3/20, f = -68.00984761828705
# Optimization restart 4/20, f = -68.00984865098982
# Optimization restart 5/20, f = -68.0098486847539
# Optimization restart 6/20, f = -68.00984796230684
# Optimization restart 7/20, f = -68.00984867329512
# Optimization restart 8/20, f = -68.00984873903857
# Optimization restart 9/20, f = -68.00984887842549
# Optimization restart 10/20, f = -68.00984888391778
# Optimization restart 11/20, f = -68.00984881586449
# Optimization restart 12/20, f = -68.009847822365
# Optimization restart 13/20, f = -68.00984868861399
# Optimization restart 14/20, f = -68.00984848771219
# Optimization restart 15/20, f = -68.00984876306457
# Optimization restart 16/20, f = -68.00984873463014
# Optimization restart 17/20, f = -68.00984817506998
# Optimization restart 18/20, f = -68.00984862883149
# Optimization restart 19/20, f = -68.00984854632705
# Optimization restart 20/20, f = -68.00984890564003
# Time it takes to do optimization 2.7855122089385986
#
#  after optimization
#
# Name : GP regression
# Objective : -68.0098489804497
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.11264807393015464  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# (55, 5)
# (55, 1)
# Optimizing the GP 2
#
#  before optimization
#
# Name : GP regression
# Objective : -69.33526429089895
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.12116836703720774  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Optimization restart 1/20, f = -70.88309266544995
# Optimization restart 2/20, f = -69.42278610854909
# Optimization restart 3/20, f = -70.88308798086466
# Optimization restart 4/20, f = -70.8830920992636
# Optimization restart 5/20, f = -70.88309226879804
# Optimization restart 6/20, f = -70.88309233187826
# Optimization restart 7/20, f = -70.88309243524188
# Optimization restart 8/20, f = -70.88309169815207
# Optimization restart 9/20, f = -70.88309204646322
# Optimization restart 10/20, f = -70.88309227956115
# Optimization restart 11/20, f = -70.883092250048
# Optimization restart 12/20, f = -70.88309161238746
# Optimization restart 13/20, f = -70.88309197572389
# Optimization restart 14/20, f = -70.88309225083708
# Optimization restart 15/20, f = -70.88309197258292
# Optimization restart 16/20, f = -70.88309180181251
# Optimization restart 17/20, f = -70.88309209452855
# Optimization restart 18/20, f = -70.88309160814639
# Optimization restart 19/20, f = -70.88309209764732
# Optimization restart 20/20, f = -70.88309193120517
# Time it takes to do optimization 2.8143370151519775
#
#  after optimization
#
# Name : GP regression
# Objective : -70.88309266544995
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.10430900741869695  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.562684646268137e-309  |      +ve      |
# Trainng 2 gp for R_AA at 7 GeV
# Optimization restart 1/20, f = -70.88309266545707
# Optimization restart 2/20, f = -70.88309222142729
# Optimization restart 3/20, f = -70.8830919410295
# Optimization restart 4/20, f = -70.88309099640117
# Optimization restart 5/20, f = -70.8830912669666
# Optimization restart 6/20, f = -70.88309224846228
# Optimization restart 7/20, f = -70.88309225029562
# Optimization restart 8/20, f = -70.88309041635709
# Optimization restart 9/20, f = -70.8830918722609
# Optimization restart 10/20, f = -70.88309242516175
# Optimization restart 11/20, f = -70.88309198284406
# Optimization restart 12/20, f = -70.88309111367371
# Optimization restart 13/20, f = -70.8830917738192
# Optimization restart 14/20, f = -70.88309222314294
# Optimization restart 15/20, f = -70.8830884366285
# Optimization restart 16/20, f = -69.42278552220144
# Optimization restart 17/20, f = -70.88309160903285
# Optimization restart 18/20, f = -70.88309191114826
# Optimization restart 19/20, f = -70.88309122768877
# Optimization restart 20/20, f = -70.88308881746669
# [[ 0.47755358  0.39251364  2.07726519  0.21513365  0.13476382]
#  [ 0.19191056  2.58534157 -0.5643841   0.2863332   0.19089391]
#  [ 0.05987234 -1.8961277  -0.07199395  0.21767414  0.12642099]
#  [ 0.30240815  2.17650933  1.31759052  0.24491485  0.2613337 ]
#  [ 0.2026532  -2.72026528 -1.03552723  0.43842999  0.17940515]
#  [ 0.28585844 -1.96123205  1.13551221  0.14107835  0.14905937]
#  [ 0.14195004  1.49724158 -0.72657178  0.26358914  0.26957855]
#  [ 0.47760806  0.94535668 -2.00172391  0.41245572  0.24883653]
#  [ 0.23509741  2.16102686 -1.96576119  0.17422015  0.30792089]
#  [ 0.34350534 -1.88775886 -2.47320619  0.41968464  0.33331067]]
# Working on 1/10 design
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# For model parameters [ 0.2026532  -2.72026528 -1.03552723  0.43842999  0.17940515] takes 70.2533700466156 S
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
# For model parameters [ 0.34350534 -1.88775886 -2.47320619  0.41968464  0.33331067] takes 117.84932518005371 S
# Optimization restart 1/20, f = -87.23391958863553
# Optimization restart 2/20, f = -88.89459975559336
# Optimization restart 3/20, f = -88.8946003859301
# Optimization restart 4/20, f = -88.89459683445108
# Optimization restart 5/20, f = -88.89460023919324
# Optimization restart 6/20, f = -88.8945995850525
# Optimization restart 7/20, f = -88.89459916141445
# Optimization restart 8/20, f = -88.89459955728935
# Optimization restart 9/20, f = -88.89460015530972
# Optimization restart 10/20, f = -88.89460026209463
# Optimization restart 11/20, f = -88.89460034780862
# Optimization restart 12/20, f = -88.89460012205453
# Optimization restart 13/20, f = -88.8945996887112
# Optimization restart 14/20, f = -87.23391892334516
# Optimization restart 15/20, f = -88.89459946607796
# Optimization restart 16/20, f = -88.89459908351009
# Optimization restart 17/20, f = -88.89459987654138
# Optimization restart 18/20, f = -88.89460006636754
# ...
#  [ 0.33861334  2.74488826  1.25978016  0.10251853  0.42674046]
#  [ 0.5        -0.82895926 -2.45156639  0.5         0.31042493]]
# Working on 1/10 design
# For model parameters [ 0.40944359 -1.8873674  -0.5830861   0.5         0.29735843] takes 191.26385712623596 S
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# For model parameters [ 0.24644404 -2.78049895  2.89574331  0.33291499  0.37568019] takes 63.40734124183655 S
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# For model parameters [0.33861334 2.74488826 1.25978016 0.10251853 0.42674046] takes 153.10406112670898 S
# Working on 10/10 design
# For model parameters [ 0.5        -0.82895926 -2.45156639  0.5         0.31042493] takes 141.84405875205994 S
# Optimization restart 1/20, f = -117.66396900844812
# Optimization restart 2/20, f = -117.66396900564564
# Optimization restart 3/20, f = -117.66396891157235
# Optimization restart 4/20, f = -113.58451855278142
# Optimization restart 5/20, f = -117.66396891552486
# Optimization restart 6/20, f = -117.66396900366655
# Optimization restart 7/20, f = -117.66396895092186
# Optimization restart 8/20, f = -117.66396900154282
# Optimization restart 9/20, f = -111.445433585843
# Optimization restart 10/20, f = -117.66396900401956
# Optimization restart 11/20, f = -117.66396900763058
# Optimization restart 12/20, f = -117.66396892159896
# Optimization restart 13/20, f = -117.66396889657429
# Optimization restart 14/20, f = -117.66396900451352
# Optimization restart 15/20, f = -117.6639687891654
# Optimization restart 16/20, f = -117.66396900691926
# Optimization restart 17/20, f = -117.66396891410555
# Optimization restart 18/20, f = -117.6639689362421
# Optimization restart 19/20, f = -117.663969008067
# Optimization restart 20/20, f = -117.66396900790127
# [[ 0.40944359 -1.8873674  -0.5830861   0.5         0.29735843]
#  [ 0.13418863 -2.71283581  2.2140925   0.5         0.31543436]
#  [ 0.05        0.33769269 -1.67185432  0.1         0.20381392]
#  [ 0.5         2.7435506   0.76672284  0.30930314  0.33175136]
#  [ 0.27920812  2.76357806  0.099131    0.5         0.25137477]
#  [ 0.24644404 -2.78049895  2.89574331  0.33291499  0.37568019]
#  [ 0.05        2.88545011 -1.56819304  0.3009353   0.27520141]
#  [ 0.36136925 -2.93961084 -1.12561143  0.13035758  0.12989855]
#  [ 0.33861334  2.74488826  1.25978016  0.10251853  0.42674046]
#  [ 0.5        -0.82895926 -2.45156639  0.5         0.31042493]]
# Working on 1/10 design
# For model parameters [ 0.40944359 -1.8873674  -0.5830861   0.5         0.29735843] takes 188.1038899421692 S
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# For model parameters [ 0.24644404 -2.78049895  2.89574331  0.33291499  0.37568019] takes 68.9161148071289 S
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# For model parameters [0.33861334 2.74488826 1.25978016 0.10251853 0.42674046] takes 147.85692286491394 S
# Working on 10/10 design
# For model parameters [ 0.5        -0.82895926 -2.45156639  0.5         0.31042493] takes 142.14307284355164 S
# (95, 5)
# (95, 1)
# Optimizing the GP 0
#
#  before optimization
#
# Name : GP regression
# Objective : -106.2238303783189
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.14985699680877268  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.0014954276647344993  |      +ve      |
# Optimization restart 1/20, f = -107.66901169259873
# Optimization restart 2/20, f = -108.44661017204399
# Optimization restart 3/20, f = -108.44661016307344
# Optimization restart 4/20, f = -108.44661017588939
# Optimization restart 5/20, f = -108.44661017618942
# Optimization restart 6/20, f = -108.44661014039175
# Optimization restart 7/20, f = -108.44661010312868
# Optimization restart 8/20, f = -108.44661017495085
# Optimization restart 9/20, f = -108.44661017399633
# Optimization restart 10/20, f = -108.4466101694251
# Optimization restart 11/20, f = -108.44661017416155
# Optimization restart 12/20, f = -108.4466101682145
# Optimization restart 13/20, f = -108.4466101452324
# Optimization restart 14/20, f = -108.44661006280843
# Optimization restart 15/20, f = -108.44661017648579
# Optimization restart 16/20, f = -108.4466099009949
# Optimization restart 17/20, f = -108.44661016821274
# Optimization restart 18/20, f = -108.44661011164848
# Optimization restart 19/20, f = -108.44661017069352
# Optimization restart 20/20, f = -108.44661017636506
# Time it takes to do optimization 1.871232032775879
#
#  after optimization
#
# Name : GP regression
# Objective : -108.44661017648579
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.16331674988831177  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.0010132679435919706  |      +ve      |
# (95, 5)
# (95, 1)
# Optimizing the GP 1
#
#  before optimization
#
# Name : GP regression
# Objective : -113.32608847465633
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.16660011572516087  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.0013569596561054805  |      +ve      |
# Optimization restart 1/20, f = -114.77110846928048
# Optimization restart 2/20, f = -114.77110868077676
# Optimization restart 3/20, f = -114.77110868424401
# Optimization restart 4/20, f = -114.771108681579
# Optimization restart 5/20, f = -114.48728117633794
# Optimization restart 6/20, f = -114.77110862380638
# Optimization restart 7/20, f = -114.77110858035888
# Optimization restart 8/20, f = -114.77110868267991
# Optimization restart 9/20, f = -114.77110868493148
# Optimization restart 10/20, f = -114.77110865604793
# Optimization restart 11/20, f = -114.77110867158045
# Optimization restart 12/20, f = -114.77110868317237
# Optimization restart 13/20, f = -114.48675123844335
# Optimization restart 14/20, f = -114.77110868325917
# Optimization restart 15/20, f = -114.77110868414664
# Optimization restart 16/20, f = -114.77110868471908
# Optimization restart 17/20, f = -114.77110868494832
# Optimization restart 18/20, f = -114.7711086840462
# Optimization restart 19/20, f = -114.77110853614239
# Optimization restart 20/20, f = -114.77110866863337
# Time it takes to do optimization 2.938840866088867
#
#  after optimization
#
# Name : GP regression
# Objective : -114.77110868494832
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.16961586208872267  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.0015075243742341182  |      +ve      |
# Trainng 0 gp for R_AA at 3 GeV
# Optimization restart 1/20, f = -108.44661017650137
# Optimization restart 2/20, f = -108.44661016592397
# Optimization restart 3/20, f = -108.44661014705844
# Optimization restart 4/20, f = -108.4466101745884
# Optimization restart 5/20, f = -108.4466101383496
# Optimization restart 6/20, f = -108.44661017216922
# Optimization restart 7/20, f = -104.21969147943703
# Optimization restart 8/20, f = -108.44661014196484
# Optimization restart 9/20, f = -108.44661016915106
# Optimization restart 10/20, f = -108.44661017590323
# Optimization restart 11/20, f = -108.44661017022467
# Optimization restart 12/20, f = -108.44661016902525
# Optimization restart 13/20, f = -108.4466101653008
# Optimization restart 14/20, f = -108.44661010660592
# Optimization restart 15/20, f = -108.4466101687016
# Optimization restart 16/20, f = -108.44661011197203
# Optimization restart 17/20, f = -108.4466101288542
# Optimization restart 18/20, f = -108.44661011434461
# Optimization restart 19/20, f = -108.44661014975733
# Optimization restart 20/20, f = -108.44661006475488
# [[ 0.49398563 -0.5296954   2.06661435  0.25441232  0.45424954]
#  [ 0.16057118  2.17513129  0.1612146   0.1109719   0.5       ]
#  [ 0.3120988   1.16062205 -2.79682112  0.32867917  0.1       ]
#  [ 0.48218156  0.29888242 -2.57389069  0.15124797  0.11458377]
#  [ 0.06362609 -2.26741836 -2.79717125  0.48240599  0.42611671]
#  [ 0.14343588 -2.24383753 -2.10330183  0.12573913  0.1       ]
#  [ 0.09440051  2.83484512  1.78077838  0.28536537  0.49173257]
#  [ 0.29867864 -2.52256107 -0.64151325  0.48858973  0.45253583]
#  [ 0.05782938  0.2787144   2.50524592  0.10800523  0.19441295]
#  [ 0.11961932  2.360005   -2.6942332   0.3584198   0.46975496]]
# Working on 1/10 design
# For model parameters [ 0.49398563 -0.5296954   2.06661435  0.25441232  0.45424954] takes 70.1470320224762 S
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# For model parameters [ 0.48218156  0.29888242 -2.57389069  0.15124797  0.11458377] takes 74.29551792144775 S
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# For model parameters [ 0.29867864 -2.52256107 -0.64151325  0.48858973  0.45253583] takes 181.1949119567871 S
# Working on 9/10 design
# Working on 10/10 design
# Optimization restart 1/20, f = -115.93633801564914
# Optimization restart 2/20, f = -115.93633753775126
# Optimization restart 3/20, f = -115.93633801256138
# Optimization restart 4/20, f = -115.9363379871315
# Optimization restart 5/20, f = -115.93633217472504
# Optimization restart 6/20, f = -115.93633801259324
# Optimization restart 7/20, f = -115.93633801442488
# Optimization restart 8/20, f = -115.93633801435375
# Optimization restart 9/20, f = -115.9363380135733
# Optimization restart 10/20, f = -115.93633795746102
# Optimization restart 11/20, f = -115.93633801369961
# Optimization restart 12/20, f = -115.93633778384603
# Optimization restart 13/20, f = -115.93633800899715
# Optimization restart 14/20, f = -115.93633800890723
# Optimization restart 15/20, f = -115.93633798673325
# Optimization restart 16/20, f = -115.93633780740984
# Optimization restart 17/20, f = -115.93633737974231
# Optimization restart 18/20, f = -115.93633799537133
# Optimization restart 19/20, f = -115.93633801332439
# Optimization restart 20/20, f = -115.93633801484452
# [[ 0.49398563 -0.5296954   2.06661435  0.25441232  0.45424954]
#  [ 0.16057118  2.17513129  0.1612146   0.1109719   0.5       ]
#  [ 0.3120988   1.16062205 -2.79682112  0.32867917  0.1       ]
#  [ 0.48218156  0.29888242 -2.57389069  0.15124797  0.11458377]
#  [ 0.06362609 -2.26741836 -2.79717125  0.48240599  0.42611671]
#  [ 0.14343588 -2.24383753 -2.10330183  0.12573913  0.1       ]
#  [ 0.09440051  2.83484512  1.78077838  0.28536537  0.49173257]
#  [ 0.29867864 -2.52256107 -0.64151325  0.48858973  0.45253583]
#  [ 0.05782938  0.2787144   2.50524592  0.10800523  0.19441295]
#  [ 0.11961932  2.360005   -2.6942332   0.3584198   0.46975496]]
# Working on 1/10 design
# For model parameters [ 0.49398563 -0.5296954   2.06661435  0.25441232  0.45424954] takes 70.42833828926086 S
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# For model parameters [ 0.48218156  0.29888242 -2.57389069  0.15124797  0.11458377] takes 73.66265916824341 S
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# For model parameters [ 0.29867864 -2.52256107 -0.64151325  0.48858973  0.45253583] takes 180.5154550075531 S
# Working on 9/10 design
# Working on 10/10 design
# (105, 5)
# (105, 1)
# Optimizing the GP 1
#
#  before optimization
#
# Name : GP regression
# Objective : -115.33612762079855
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.16961586208872267  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.0015075243742341182  |      +ve      |
# Optimization restart 1/20, f = -118.01566060044061
# Optimization restart 2/20, f = -120.07946621727001
# Optimization restart 3/20, f = -120.07946621588673
# Optimization restart 4/20, f = -120.07946621686995
# Optimization restart 5/20, f = -120.0794661854536
# Optimization restart 6/20, f = -120.07946615037059
# Optimization restart 7/20, f = -120.07946618001321
# Optimization restart 8/20, f = -120.07946599726533
# Optimization restart 9/20, f = -120.07946621713185
# Optimization restart 10/20, f = -120.07946621533598
# Optimization restart 11/20, f = -120.07946621022687
# Optimization restart 12/20, f = -120.07946621489465
# Optimization restart 13/20, f = -120.07946621171892
# Optimization restart 14/20, f = -120.0794662093682
# Optimization restart 15/20, f = -120.07946621478091
# Optimization restart 16/20, f = -120.07946621325397
# Optimization restart 17/20, f = -120.07946621693769
# Optimization restart 18/20, f = -120.07946621652181
# Optimization restart 19/20, f = -120.07946616551745
# Optimization restart 20/20, f = -120.07946612387687
# Time it takes to do optimization 2.1973838806152344
#
#  after optimization
#
# Name : GP regression
# Objective : -120.07946621727001
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.15359395506017653  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.00034061686083804686  |      +ve      |
# (105, 5)
# (105, 1)
# Optimizing the GP 2
#
#  before optimization
#
# Name : GP regression
# Objective : -118.62030731578972
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   rbf.variance             |   0.16553407475521326  |      +ve      |
#   rbf.lengthscale          |                  (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.001311234552132247  |      +ve      |
# Optimization restart 1/20, f = -121.5622637366321
# Optimization restart 2/20, f = -121.75370473215078
# Optimization restart 3/20, f = -121.75370462469071
# Optimization restart 4/20, f = -121.75370472759262
# Optimization restart 5/20, f = -121.75370473285645
# Optimization restart 6/20, f = -121.7537047311729
# Optimization restart 7/20, f = -121.75370471994172
# Optimization restart 8/20, f = -121.75370473182626
# Optimization restart 9/20, f = -121.75370473282545
# Optimization restart 10/20, f = -121.75370470668496
# Optimization restart 11/20, f = -121.75370468110648
# Optimization restart 12/20, f = -121.75370473054957
# Optimization restart 13/20, f = -121.75370469735135
# Optimization restart 14/20, f = -121.75370472881518
# Optimization restart 15/20, f = -121.75370473234062
# Optimization restart 16/20, f = -121.7537045500328
# Optimization restart 17/20, f = -121.75370472544192
# Optimization restart 18/20, f = -121.75370473278716
# Optimization restart 19/20, f = -121.75370473186275
# Optimization restart 20/20, f = -121.75370472273173
# Time it takes to do optimization 2.070754051208496
#
#  after optimization
#
# Name : GP regression
# Objective : -121.75370473285645
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.14876703911078404  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.00031724586280979335  |      +ve      |
# Total time for this cell -31813.655972719193 S

# %%
def emu_predict0(X):
    y, variance_dy = gp_array[0].predict(X)
    dy = np.sqrt(variance_dy)
    #y = scaler_0.inverse_transform(scaled_y)
    #dy = scaled_dy* scaler_0.scale_
    return y, dy.flatten()

def emu_predict1(X):
    y, variance_dy = gp_array[1].predict(X)
    dy = np.sqrt(variance_dy)
    #y = scaler_0.inverse_transform(scaled_y)
    #dy = scaled_dy* scaler_0.scale_
    return y, dy.flatten()

def emu_predict2(X):
    y, variance_dy = gp_array[2].predict(X)
    dy = np.sqrt(variance_dy)
    #y = scaler_0.inverse_transform(scaled_y)
    #dy = scaled_dy* scaler_0.scale_
    return y, dy.flatten()

# %%
#make a regular grid to plot our Emulator predictions
n_plot_pts = 100
sim_pnt = 10
test_points = np.array([[x,true_values['exponent_inel'],
                 true_values['exponent_el'],true_values['scale_inel'],true_values['scale_el']] for x in np.linspace(prior_ranges['alpha_s'][0],prior_ranges['alpha_s'][1],n_plot_pts)])
simulation_out = simulation(test_points[np.arange(0,n_plot_pts,sim_pnt),:],*pT_range)[:,pT_obs]
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),0], simulation_out[:,0],'ro', label='sim pT_obs[0]')
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),0], simulation_out[:,1],'go', label='sim pT_obs[1]')
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),0], simulation_out[:,2], 'bo', label='sim pT_obs[2]')


#get the GP Emulator's predictions of both the mean and std. deviation
gp_y0, gp_dy0 = emu_predict0(test_points)
gp_y1, gp_dy1 = emu_predict1(test_points)
gp_y2, gp_dy2 = emu_predict2(test_points)


plt.plot(test_points[:,0], gp_y0[:,0], color='red', label='pT_obs[0]')
plt.plot(test_points[:,0], gp_y1[:,0], color='green', label='pT_obs[1]')
plt.plot(test_points[:,0], gp_y2[:,0], color='blue', label='pT_obs[2]')
plt.fill_between(test_points[:,0], y1 = gp_y0[:,0] - 2.*gp_dy0, y2 = gp_y0[:,0] + 2.*gp_dy0, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='red')
plt.fill_between(test_points[:,0], y1 = gp_y1[:,0] - 2.*gp_dy1, y2 = gp_y1[:,0] + 2.*gp_dy1, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='green')
plt.fill_between(test_points[:,0], y1 = gp_y2[:,0] - 2.*gp_dy2, y2 = gp_y2[:,0] + 2.*gp_dy2, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='blue')

plt.xlabel(r'$\alpha_s$')
plt.ylabel(r'$R_{AA}$')
plt.title(r'GP Emulator and Model Training Points')
plt.legend()
plt.tight_layout(True)

plt.show()
# Out:
# Working on 1/10 design
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# For model parameters [ 0.41363636 -1.          1.          0.3         0.3       ] takes 65.84648776054382 S
# Working on 10/10 design
# For model parameters [ 0.45909091 -1.          1.          0.3         0.3       ] takes 82.41214418411255 S
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning:Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %%
#make a regular grid to plot our Emulator predictions
n_plot_pts = 100
sim_pnt = 10
test_points = np.array([[true_values['alpha_s'],x,
                 true_values['exponent_el'],true_values['scale_inel'],true_values['scale_el']] for x in np.linspace(prior_ranges['exponent_inel'][0],prior_ranges['exponent_inel'][1],n_plot_pts)])

simulation_out = simulation(test_points[np.arange(0,n_plot_pts,sim_pnt),:],*pT_range)[:,pT_obs]
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),1], simulation_out[:,0],'ro', label='sim pT_obs[0]')
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),1], simulation_out[:,1],'go', label='sim pT_obs[1]')
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),1], simulation_out[:,2], 'bo', label='sim pT_obs[2]')


#get the GP Emulator's predictions of both the mean and std. deviation
gp_y0, gp_dy0 = emu_predict0(test_points)
gp_y1, gp_dy1 = emu_predict1(test_points)
gp_y2, gp_dy2 = emu_predict2(test_points)

plt.plot(test_points[:,1], gp_y0[:,0], color='red', label='pT_obs[0]')
plt.plot(test_points[:,1], gp_y1[:,0], color='green', label='pT_obs[1]')
plt.plot(test_points[:,1], gp_y2[:,0], color='blue', label='pT_obs[2]')
plt.fill_between(test_points[:,1], y1 = gp_y0[:,0] - 2.*gp_dy0, y2 = gp_y0[:,0] + 2.*gp_dy0, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='red')
plt.fill_between(test_points[:,1], y1 = gp_y1[:,0] - 2.*gp_dy1, y2 = gp_y1[:,0] + 2.*gp_dy1, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='green')
plt.fill_between(test_points[:,1], y1 = gp_y2[:,0] - 2.*gp_dy2, y2 = gp_y2[:,0] + 2.*gp_dy2, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='blue')

plt.xlabel(r'exp_inel')
plt.ylabel(r'$R_{AA}$')
plt.title(r'GP Emulator and Model Training Points')
plt.legend()
plt.tight_layout(True)

plt.show()
# Out:
# Working on 1/10 design
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning:dopri5: step size becomes too small
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning:dopri5: larger nsteps is needed
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning:Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %%
#make a regular grid to plot our Emulator predictions
n_plot_pts = 100
sim_pnt = 10
test_points = np.array([[true_values['alpha_s'],true_values['exponent_inel'],
                 x,true_values['scale_inel'],true_values['scale_el']] for x in np.linspace(prior_ranges['exponent_el'][0],prior_ranges['exponent_el'][1],n_plot_pts)])

simulation_out = simulation(test_points[np.arange(0,n_plot_pts,sim_pnt),:],*pT_range)[:,pT_obs]
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),2], simulation_out[:,0],'ro', label='sim pT_obs[0]')
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),2], simulation_out[:,1],'go', label='sim pT_obs[1]')
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),2], simulation_out[:,2], 'bo', label='sim pT_obs[2]')


#get the GP Emulator's predictions of both the mean and std. deviation
gp_y0, gp_dy0 = emu_predict0(test_points)
gp_y1, gp_dy1 = emu_predict1(test_points)
gp_y2, gp_dy2 = emu_predict2(test_points)

plt.plot(test_points[:,2], gp_y0[:,0], color='red', label='pT_obs[0]')
plt.plot(test_points[:,2], gp_y1[:,0], color='green', label='pT_obs[1]')
plt.plot(test_points[:,2], gp_y2[:,0], color='blue', label='pT_obs[2]')
plt.fill_between(test_points[:,2], y1 = gp_y0[:,0] - 2.*gp_dy0, y2 = gp_y0[:,0] + 2.*gp_dy0, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='red')
plt.fill_between(test_points[:,2], y1 = gp_y1[:,0] - 2.*gp_dy1, y2 = gp_y1[:,0] + 2.*gp_dy1, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='green')
plt.fill_between(test_points[:,2], y1 = gp_y2[:,0] - 2.*gp_dy2, y2 = gp_y2[:,0] + 2.*gp_dy2, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='blue')

plt.xlabel(r'exp_el')
plt.ylabel(r'$R_{AA}$')
plt.title(r'GP Emulator and Model Training Points')
#plt.legend()
plt.tight_layout(True)

plt.show()
# Out:
# Working on 1/10 design
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning:dopri5: step size becomes too small
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning:dopri5: larger nsteps is needed
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning:Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %%
#make a regular grid to plot our Emulator predictions
n_plot_pts = 100
sim_pnt = 10
test_points = np.array([[true_values['alpha_s'],true_values['exponent_inel'],
                 true_values['exponent_el'],x,true_values['scale_el']] for x in np.linspace(prior_ranges['scale_inel'][0],prior_ranges['scale_inel'][1],n_plot_pts)])

simulation_out = simulation(test_points[np.arange(0,n_plot_pts,sim_pnt),:],*pT_range)[:,pT_obs]
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),3], simulation_out[:,0],'ro', label='sim pT_obs[0]')
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),3], simulation_out[:,1],'go', label='sim pT_obs[1]')
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),3], simulation_out[:,2], 'bo', label='sim pT_obs[2]')


#get the GP Emulator's predictions of both the mean and std. deviation
gp_y0, gp_dy0 = emu_predict0(test_points)
gp_y1, gp_dy1 = emu_predict1(test_points)
gp_y2, gp_dy2 = emu_predict2(test_points)

plt.plot(test_points[:,3], gp_y0[:,0], color='red', label='pT_obs[0]')
plt.plot(test_points[:,3], gp_y1[:,0], color='green', label='pT_obs[1]')
plt.plot(test_points[:,3], gp_y2[:,0], color='blue', label='pT_obs[2]')
plt.fill_between(test_points[:,3], y1 = gp_y0[:,0] - 2.*gp_dy0, y2 = gp_y0[:,0] + 2.*gp_dy0, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='red')
plt.fill_between(test_points[:,3], y1 = gp_y1[:,0] - 2.*gp_dy1, y2 = gp_y1[:,0] + 2.*gp_dy1, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='green')
plt.fill_between(test_points[:,3], y1 = gp_y2[:,0] - 2.*gp_dy2, y2 = gp_y2[:,0] + 2.*gp_dy2, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='blue')

plt.xlabel(r'scale_inel')
plt.ylabel(r'$R_{AA}$')
plt.title(r'GP Emulator and Model Training Points')
#plt.legend()
plt.tight_layout(True)

plt.show()
# Out:
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning:dopri5: step size becomes too small
# Working on 1/10 design
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning:dopri5: larger nsteps is needed
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning:Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %%
#make a regular grid to plot our Emulator predictions
n_plot_pts = 100
sim_pnt = 10
test_points = np.array([[true_values['alpha_s'],true_values['exponent_inel'],
                 true_values['exponent_el'],true_values['scale_inel'],x] for x in np.linspace(prior_ranges['scale_el'][0],prior_ranges['scale_el'][1],n_plot_pts)])

simulation_out = simulation(test_points[np.arange(0,n_plot_pts,sim_pnt),:],*pT_range)[:,pT_obs]
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),4], simulation_out[:,0],'ro', label='sim pT_obs[0]')
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),4], simulation_out[:,1],'go', label='sim pT_obs[1]')
plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),4], simulation_out[:,2], 'bo', label='sim pT_obs[2]')


#get the GP Emulator's predictions of both the mean and std. deviation
gp_y0, gp_dy0 = emu_predict0(test_points)
gp_y1, gp_dy1 = emu_predict1(test_points)
gp_y2, gp_dy2 = emu_predict2(test_points)

plt.plot(test_points[:,4], gp_y0[:,0], color='red', label='pT_obs[0]')
plt.plot(test_points[:,4], gp_y1[:,0], color='green', label='pT_obs[1]')
plt.plot(test_points[:,4], gp_y2[:,0], color='blue', label='pT_obs[2]')
plt.fill_between(test_points[:,4], y1 = gp_y0[:,0] - 2.*gp_dy0, y2 = gp_y0[:,0] + 2.*gp_dy0, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='red')
plt.fill_between(test_points[:,4], y1 = gp_y1[:,0] - 2.*gp_dy1, y2 = gp_y1[:,0] + 2.*gp_dy1, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='green')
plt.fill_between(test_points[:,4], y1 = gp_y2[:,0] - 2.*gp_dy2, y2 = gp_y2[:,0] + 2.*gp_dy2, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='blue')

plt.xlabel(r'scale_el')
plt.ylabel(r'$R_{AA}$')
plt.title(r'GP Emulator and Model Training Points')
#plt.legend()
plt.tight_layout(True)

plt.show()
# Out:
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning:dopri5: step size becomes too small
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/scipy/integrate/_ode.py:1180: UserWarning:dopri5: larger nsteps is needed
# Working on 1/10 design
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /Users/dananjayaliyanage/git/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on 2/10 design
# Working on 3/10 design
# Working on 4/10 design
# Working on 5/10 design
# Working on 6/10 design
# Working on 7/10 design
# Working on 8/10 design
# Working on 9/10 design
# Working on 10/10 design
#  /Users/dananjayaliyanage/miniconda3/envs/parton_loss/lib/python3.6/site-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning:Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %%
design = gp_array[0].X
for i in range(0,5):
    for k in range(0,i):
        fig, ax = plt.subplots()
        ax.scatter(design[:,i],design[:,k])
        ax.set_xlabel(f'{list(prior_ranges.keys())[i]}')
        ax.set_ylabel(f'{list(prior_ranges.keys())[k]}')

# %%
# Define the loglikelihood function
def logLikelihood(theta, x, obs, obserr):
  
    # Model parameters
    theta = np.array(theta)
    
    #alpha_s, mD_factor, exponent_inel, exponent_el = theta
    alpha_s, exp_inel, exp_el, sc_inel, sc_el = theta
    design = np.array([alpha_s, exp_inel, exp_el, sc_inel, sc_el]).reshape(1,-1)
    
    # Model predictions given parameters
    
    model = np.array([emu_predict0(design),emu_predict1(design),emu_predict2(design)],dtype=object)
    modelerr = model[:,1]
    model = model[:,0]
    
    # Likelihood of data given model parameters

    term2 = 0.5*(2*np.pi*np.sqrt(np.sum(obserr**2+modelerr.flatten()**2)))
    return -0.5*np.sum((obs.flatten()-model.flatten())**2/(obserr**2+modelerr.flatten()**2)) - term2

# %%
logLikelihood(truth.flatten(),x,obs,obserr)
# Out:
# -0.6456035352990741

# %%
# Define the logprior function
def logPrior(theta):
    
    # Model parameters
    theta = np.array(theta)
    alpha_s, exp_inel, exp_el, sc_inel, sc_el = theta 
    
    # Probability of model parameters: flat prior
    if prior_ranges['alpha_s'][0] < alpha_s < prior_ranges['alpha_s'][1] \
        and prior_ranges['exponent_inel'][0] < exp_inel < prior_ranges['exponent_inel'][1] \
        and prior_ranges['exponent_el'][0] < exp_el < prior_ranges['exponent_el'][1]\
        and prior_ranges['scale_inel'][0] < sc_inel < prior_ranges['scale_inel'][1] \
        and prior_ranges['scale_el'][0] < sc_el < prior_ranges['scale_el'][1]:
        return 0.0
    return -np.inf

# %%
# Define logprobability function: l(D|theta) * p(theta)
# Note: use this for emcee, not approxposterior!
def logposterior(theta, x, obs, obserr):
        
    lp = logPrior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + logLikelihood(theta, x, obs, obserr)

# %%
ntemps = 25
Tmax = 1e3

nwalkers = 50 #guidance is 10*d
ndim = 5
nburnin = 2000
niterations= 5000
nthin = 1#0 # only record every nthin iteration

nthreads = 4

min_theta = np.array([prior_ranges['alpha_s'][0],prior_ranges['exponent_inel'][0],prior_ranges['exponent_el'][0],prior_ranges['scale_inel'][0],prior_ranges['scale_el'][0]])
max_theta = np.array([prior_ranges['alpha_s'][1],prior_ranges['exponent_inel'][1],prior_ranges['exponent_el'][1],prior_ranges['scale_inel'][1],prior_ranges['scale_el'][1]])

# Data and uncertainties that we use to condition our model
args = (x, obs, obserr) # recall x = np.array(pT_obs)

ptsampler=ptemcee.Sampler(nwalkers, ndim, logLikelihood, logPrior, ntemps, 
                  threads=nthreads, Tmax=Tmax, loglargs=args)

# Making the sampling multi-threaded is as simple as adding the threads=Nthreads 
# argument to PTSampler. 

# First, we run the sampler for 1000 burn-in iterations:
pos0 = np.random.uniform(min_theta, max_theta, (ntemps, nwalkers, ndim))

print("Running burn-in phase")
for p, lnprob, lnlike in ptsampler.sample(pos0, iterations=nburnin,adapt=True):
    pass
ptsampler.reset()

print("Running MCMC chains")
#Now we sample for nwalkers*niterations, recording every nthin-th sample:
for p, lnprob, lnlike in ptsampler.sample(p, iterations=niterations, thin=nthin,adapt=True):
    pass 

print('Done MCMC')

mean_acc_frac = np.mean(ptsampler.acceptance_fraction)
print(f"Mean acceptance fraction: {mean_acc_frac:.3f}",
      f"(in total {nwalkers*niterations} steps)")
# Out:
# Running burn-in phase
# Running MCMC chains
# Done MCMC
# Mean acceptance fraction: 0.295 (in total 250000 steps)

# %%
chain = ptsampler.chain[0, :, :, :].reshape((-1, ndim))

# %%
fig = corner.corner(chain, quantiles=[0.16, 0.5, 0.84], truths=truth.T,
                    labels=[r"$\alpha_s$", 'exponent_inel', 'exponent_el','scale_inel','scale_el'], show_titles=True, scale_hist=True,
                    plot_contours=True, range=(prior_ranges.values()));
plt.tight_layout()
plt.savefig('corner-lhsgp-ptemcee.png',dpi=600)
plt.show()
