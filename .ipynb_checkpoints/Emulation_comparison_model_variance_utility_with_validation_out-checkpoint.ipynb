# %% [markdown]
# ## We will compare the performance of a GP trained using two methods.
# > Min Max Latin HyperCube Sampling
#
# > Active learning sampling (Emukit)

# %% [markdown]
# # For this notebook we have used old validation points which were out of prior bounds

# %% [markdown]
# ### Generate 50 initial design points using LHS which will be used as common initial data for both methods

# %%
from emukit.core.initial_designs.latin_design import LatinDesign
from emukit.core import ParameterSpace, ContinuousParameter

import run_simple_energy_loss_parallel_pool

import pandas as pd
import numpy as np

import os

# %%
simulation = run_simple_energy_loss_parallel_pool.run_simulation

# %%
pT_range = (1, 10, 10) # Compute more observable than needed to avoid boundry unstabilities.
pT_obs = [5] # p_T Observables we will use for the analysis

# %%
parameter_space = ParameterSpace([ContinuousParameter('alpha_s', 0.1,0.4 ),
                                  ContinuousParameter('exponent_inel', -2, 2),
                                  ContinuousParameter('exponent_el', -2, 2),
                                  ContinuousParameter('scale_inel', 0.1, 0.4),
                                  ContinuousParameter('scale_el', 0.1, 0.4)])

# %%
param_keys = ['alpha_s','exponent_inel','exponent_el','scale_inel', 'scale_el']
result_keys = ['pT {} GeV'.format(str(i)) for i in np.linspace(*pT_range)]
clms_names = np.hstack((param_keys,result_keys))
print(clms_names)
# Out:
# ['alpha_s' 'exponent_inel' 'exponent_el' 'scale_inel' 'scale_el'
#  'pT 1.0 GeV' 'pT 2.0 GeV' 'pT 3.0 GeV' 'pT 4.0 GeV' 'pT 5.0 GeV'
#  'pT 6.0 GeV' 'pT 7.0 GeV' 'pT 8.0 GeV' 'pT 9.0 GeV' 'pT 10.0 GeV']

# %%
if os.path.exists('lhs.csv'):
    lhs_df = pd.read_csv('lhs.csv')
    
else:
    design = LatinDesign(parameter_space) 
    # Keep the first 50 as initial training point for active learning. 
    # Use all 100 to train a GP
    num_data_points = 100 
    X = design.get_samples(num_data_points)
    Y_all = simulation(X,*pT_range)
    lhs_data=np.hstack((X,Y_all))
    print(lhs_data.shape)
    print('saving the lhs to a csv file')
    lhs_df = pd.DataFrame(lhs_data,columns=clms_names)
    # Write dataframe to file
    lhs_df.to_csv('lhs.csv', index = False)

# %%
lhs_df.head()
# Out:
#    alpha_s  exponent_inel  exponent_el  scale_inel  scale_el  pT 1.0 GeV  \
# 0  0.26375           1.83         2.97       0.122     0.342    0.894801
# 1  0.14675           2.73         2.79       0.410     0.118    0.784344
# 2  0.45275          -2.07        -2.91       0.318     0.274    0.133746
# 3  0.41675          -0.81         1.77       0.458     0.254    0.622836
# 4  0.23225           2.13         1.23       0.398     0.462    0.865353
#
#    pT 2.0 GeV  pT 3.0 GeV  pT 4.0 GeV  pT 5.0 GeV  pT 6.0 GeV  pT 7.0 GeV  \
# 0    1.027984    0.234381    0.122653    0.084964    0.067698    0.058394
# 1    0.798790    0.681841    0.641078    0.622577    0.613761    0.609859
# 2    0.224321    0.000443    0.000027    0.000006    0.000002    0.000001
# 3    0.858052    0.021496    0.004504    0.001928    0.001163    0.000837
# 4    0.905545    0.588398    0.493834    0.451249    0.428896    0.416236
#
#      pT 8.0 GeV    pT 9.0 GeV   pT 10.0 GeV
# 0  5.248037e-02  4.730002e-02  4.129106e-02
# 1  6.082962e-01  6.061083e-01  6.001121e-01
# 2  6.219523e-07  3.522860e-07  1.877460e-07
# 3  6.513225e-04  5.093071e-04  3.824464e-04
# 4  4.082844e-01  4.007987e-01  3.901686e-01

# %%
X_all = np.array(lhs_df.iloc[:,:5])
Y_all = np.array(lhs_df.iloc[:,5:])
X_init = X_all[:50,:]
Y_init = Y_all[:50,:]

print(f'Shape of initial design {X_init.shape} and initial observables {Y_init.shape}')
# Out:
# Shape of initial design (50, 5) and initial observables (50, 10)

# %%
# Load validation data
validation_df = pd.read_csv('validation.csv', index_col=0)
X_valid = np.array(validation_df.iloc[:,:5])
Y_valid = np.array(validation_df.iloc[:,5:])
print(f'Shape of validation design {X_valid.shape} and validation observables {Y_valid.shape}')
# Out:
# Shape of validation design (100, 5) and validation observables (100, 10)

# %% [markdown]
# ## Need to write a function that runs iteratively adding more design points and train both type of gps.
# > plots should have how rms error decreases for the two types with time
#
# > How predictions at the truth compare at each steps of sampling

# %%
prior_ranges= {'alpha_s':(0.1,0.4), 'exponent_inel':(-2,2), 'exponent_el':(-2,2), 'scale_inel':(0.1, 0.4), 'scale_el':(0.1, 0.4)}
true_values= {'alpha_s': 0.2, 'exponent_inel': -1, 'exponent_el': 1, 'scale_inel': 0.3, 'scale_el': 0.3}
name_to_position =  {'alpha_s':0, 'exponent_inel':1, 'exponent_el':2, 'scale_inel':3, 'scale_el':4}
truth = np.array([true_values['alpha_s'],  true_values['exponent_inel'],
                 true_values['exponent_el'],true_values['scale_inel'],true_values['scale_el']]).reshape(1,-1)

# %%
# define the two types of gp we will use
from GPy.kern import RBF, White
from GPy.models import GPRegression
from emukit.model_wrappers import GPyModelWrapper

# %%
# size of possible variation of parameters
ptp = np.array([prior_ranges['alpha_s'][1],prior_ranges['exponent_inel'][1],prior_ranges['exponent_el'][1],prior_ranges['scale_inel'][1],prior_ranges['scale_el'][1]])\
-np.array([prior_ranges['alpha_s'][0],prior_ranges['exponent_inel'][0],prior_ranges['exponent_el'][0],prior_ranges['scale_inel'][0],prior_ranges['scale_el'][0]])

#gp_array = []

rbf_kern_1 =  RBF(input_dim=5, variance= 1, lengthscale=ptp, ARD=True)
my_kernel_1 = rbf_kern_1
model_gpy_1 = GPRegression(X=X_init, Y=Y_init[:, pT_obs], kernel=my_kernel_1, noise_var=0.01**2)
model_gpy_1.optimize_restarts(num_restarts = 30)
model_emukit_1 = GPyModelWrapper(model_gpy_1, n_restarts=30)
    
rbf_kern_2 =  RBF(input_dim=5, variance= 1, lengthscale=ptp, ARD=True)
my_kernel_2 = rbf_kern_2
model_gpy_2 = GPRegression(X=X_init, Y=Y_init[:, pT_obs], kernel=my_kernel_2, noise_var=0.01**2)
model_gpy_2.optimize_restarts(num_restarts = 30)
model_emukit_2 = GPyModelWrapper(model_gpy_2, n_restarts=30)
    
gp_array = [model_emukit_1, model_emukit_2]
# Out:
# Optimization restart 1/30, f = -57.59134053111302
# Optimization restart 2/30, f = -57.59134064358395
# Optimization restart 3/30, f = -57.591340331027205
# Optimization restart 4/30, f = -56.83271064308728
# Optimization restart 5/30, f = -57.59134059077657
# Optimization restart 6/30, f = -57.59133987648834
# Optimization restart 7/30, f = -57.59133988615649
# Optimization restart 8/30, f = -57.591340528015834
# Optimization restart 9/30, f = -57.59133796697896
# Optimization restart 10/30, f = -57.591340486258055
# Optimization restart 11/30, f = -56.83271060568269
# Optimization restart 12/30, f = -57.59134035611618
# Optimization restart 13/30, f = -56.8327106170284
# Optimization restart 14/30, f = -57.59133385594953
# Optimization restart 15/30, f = -57.59133951612425
# Optimization restart 16/30, f = -57.59134060591903
# Optimization restart 17/30, f = -57.59134064765708
# Optimization restart 18/30, f = -57.59134057338399
# Optimization restart 19/30, f = -57.59134047846781
# Optimization restart 20/30, f = -56.83271065938022
# Optimization restart 21/30, f = -57.089479953556506
# Optimization restart 22/30, f = -56.83271066090597
# Optimization restart 23/30, f = -54.91708481986125
# Optimization restart 24/30, f = -56.83271065302342
# Optimization restart 25/30, f = -56.832710661901054
# Optimization restart 26/30, f = -57.59134054043888
# Optimization restart 27/30, f = -57.59134061267896
# Optimization restart 28/30, f = -57.59134059825021
# Optimization restart 29/30, f = -56.832710660291525
# Optimization restart 30/30, f = -57.59134033238524
# Optimization restart 1/30, f = -57.59134053112432
# Optimization restart 2/30, f = -57.59134059578769
# Optimization restart 3/30, f = -57.59134064094401
# Optimization restart 4/30, f = -57.591340358716465
# Optimization restart 5/30, f = -56.832710635816596
# Optimization restart 6/30, f = -57.591340539172066
# Optimization restart 7/30, f = -57.59134058830692
# Optimization restart 8/30, f = -56.832710548416394
# Optimization restart 9/30, f = -56.83271066191891
# Optimization restart 10/30, f = -57.591340570763634
# Optimization restart 11/30, f = -57.5913405822275
# Optimization restart 12/30, f = -57.59134062883775
# Optimization restart 13/30, f = -52.549073026027195
# Optimization restart 14/30, f = -57.591340345848934
# Optimization restart 15/30, f = -57.59134031484393
# Optimization restart 16/30, f = -57.59133664200463
# Optimization restart 17/30, f = -57.59134055721383
# Optimization restart 18/30, f = -57.59134012263304
# Optimization restart 19/30, f = -57.59133979612425
# Optimization restart 20/30, f = -57.591340463191685
# Optimization restart 21/30, f = -57.5913405684752
# Optimization restart 22/30, f = -52.55609361462143
# Optimization restart 23/30, f = -57.59134044386708
# Optimization restart 24/30, f = -57.59134016177772
# Optimization restart 25/30, f = -57.591340509537794
# Optimization restart 26/30, f = -57.59134046902272
# Optimization restart 27/30, f = -57.59134062957827
# Optimization restart 28/30, f = -57.5913406379374
# Optimization restart 29/30, f = -57.59134008990931
# Optimization restart 30/30, f = -57.591339608036236

# %%
gp_array[0].Y[:,0].shape
# Out:
# (50,)

# %%
from emukit.experimental_design.acquisitions import IntegratedVarianceReduction, ModelVariance
from emukit.experimental_design import ExperimentalDesignLoop

# %%
def f(design, pT=pT_obs[0]):
    """returns simulation output for a design matrix"""
    print(f'design is {design}')
    observables=simulation(design,*pT_range)
    #Let's just return only one obsrvable for now. The middle p_T bin
    return observables[:,pT].reshape(-1,1)

# %%
def emu_predict(X, gp):
    y, variance_dy = gp.predict(X)
    dy = np.sqrt(variance_dy)
    #y = scaler_0.inverse_transform(scaled_y)
    #dy = scaled_dy* scaler_0.scale_
    return y, dy.flatten()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse
def compare_gp(gp_1,gp_2):
    #make a regular grid to plot our Emulator predictions
    n_plot_pts = 100
    sim_pnt = 10
    for name in prior_ranges.keys():
        test_points = np.repeat(truth, 100, axis = 0)
        pos = name_to_position[name]
        test_points[:,pos] = np.linspace(*prior_ranges[name],100)
        simulation_out = simulation(test_points[np.arange(0,n_plot_pts,sim_pnt),:],*pT_range)[:,pT_obs]
        plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),pos], simulation_out[:,0],'ro', label=f'sim {pT_obs[0]} GeV')
#plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),0], simulation_out[:,1],'go', label='sim pT_obs[1]')
#plt.plot(test_points[np.arange(0,n_plot_pts,sim_pnt),0], simulation_out[:,2], 'bo', label='sim pT_obs[2]')


#get the GP Emulator's predictions of both the mean and std. deviation
        gp_y0, gp_dy0 = emu_predict(test_points, gp_1)
        gp_y1, gp_dy1 = emu_predict(test_points, gp_2)
#gp_y2, gp_dy2 = emu_predict2(test_points)


        plt.plot(test_points[:,pos], gp_y0[:,0], color='red', label='Emukit')
        plt.plot(test_points[:,pos], gp_y1[:,0], color='blue', label='lhs')
#plt.plot(test_points[:,0], gp_y2[:,0], color='blue', label='pT_obs[2]')
        plt.fill_between(test_points[:,pos], y1 = gp_y0[:,0] - 2.*gp_dy0, y2 = gp_y0[:,0] + 2.*gp_dy0, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='red')
        plt.fill_between(test_points[:,pos], y1 = gp_y1[:,0] - 2.*gp_dy1, y2 = gp_y1[:,0] + 2.*gp_dy1, 
                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='blue')
#plt.fill_between(test_points[:,0], y1 = gp_y2[:,0] - 2.*gp_dy2, y2 = gp_y2[:,0] + 2.*gp_dy2, 
#                 interpolate=True, alpha=0.3, label=r'GP 2$\sigma$', color='blue')

        plt.xlabel(name)
        plt.ylabel(r'$R_{AA}$')
        plt.title(f'LHS {gp_1.X.shape[0]}, Emukit {gp_2.X.shape[0]}')
        plt.legend()
        plt.tight_layout(True)

        plt.show()
        
    gp1_validation,_ = emu_predict(X_valid,gp_1)
    gp2_validation,_ = emu_predict(X_valid,gp_2)
    validation_score = [mse(Y_valid[:,pT_obs[0]],gp1_validation, squared=False),
                        mse(Y_valid[:,pT_obs[0]],gp2_validation, squared=False)]
    return validation_score

# %%
import time
time_iter = []
validation_array = []
bs = 5

# The active learning GP
GP_al = gp_array[0]
    
 # LHS GP
GP_lhs = gp_array[1]

for i in range(0,10):
    st = time.time()
    integrated_var = ModelVariance(model = GP_al)
    #integrated_var = IntegratedVarianceReduction(model = GP_al, space=parameter_space)
    expdesign_loop = ExperimentalDesignLoop(model = GP_al,
                                         space = parameter_space,
                                         acquisition = integrated_var,
                                         batch_size = bs)
    print('######################')
    print('AL before hyperparameters are\n')
    print(GP_al.model)
    ed=expdesign_loop.run_loop(f,1)
    print('######################')
    print('AL After hyperparameters are \n')
    print(GP_al.model)    

    GP_lhs.set_data(X_all[:50+bs*(i+1),:], Y_all[:50+bs*(i+1),  pT_obs])
    print('######################')
    print('LHS before hyperparameters are\n')
    print(GP_lhs.model)
    GP_lhs.optimize()
    print('######################')
    print('LHS After hyperparameters are\n')
    print(GP_lhs.model)
    
    print(f'time taken for the iteraton {i} is {time.time()-st} S')
    time_iter.append(time.time()-st)
    val = compare_gp(GP_al, GP_lhs)
    validation_array.append(val)
    print('#################### \n ######################')
    print(f'Validation score for {i} iteration AL {val[0]} , LHS {val[1]}')
# Out:
# ######################
# AL before hyperparameters are
#
#
# Name : GP regression
# Objective : -57.59134064765708
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |  priors
#   rbf.variance             |     0.16379735602185252  |      +ve      |
#   rbf.lengthscale          |                    (5,)  |      +ve      |
#   Gaussian_noise.variance  |  3.5354300175054682e-12  |      +ve      |
# Optimization restart 1/30, f = -57.59134065321244
# Optimization restart 2/30, f = -57.59134058224056
# Optimization restart 3/30, f = -56.832710659888775
# Optimization restart 4/30, f = -57.59133939615107
# Optimization restart 5/30, f = -56.832710656407784
# Optimization restart 6/30, f = -57.59134040219532
# Optimization restart 7/30, f = -57.59134051998975
# Optimization restart 8/30, f = -56.832710650535525
# Optimization restart 9/30, f = -56.83271065907074
# Optimization restart 10/30, f = -57.59134047221984
# Optimization restart 11/30, f = -57.591340482985544
# Optimization restart 12/30, f = -57.591340432409524
# Optimization restart 13/30, f = -56.83271032700582
# Optimization restart 14/30, f = -57.59134052624039
# Optimization restart 15/30, f = -56.83271060508272
# Optimization restart 16/30, f = -57.59134048529573
# Optimization restart 17/30, f = -56.83271064829852
# Optimization restart 18/30, f = -57.59134019965656
# Optimization restart 19/30, f = -57.591340556301695
# Optimization restart 20/30, f = -57.59134042919992
# Optimization restart 21/30, f = -57.591340475515985
# Optimization restart 22/30, f = -57.591340485669264
# Optimization restart 23/30, f = -57.591340278618695
# Optimization restart 24/30, f = -57.59134035731827
# Optimization restart 25/30, f = -56.832710409735334
# Optimization restart 26/30, f = -57.59134031105135
# Optimization restart 27/30, f = -57.59134032123035
# Optimization restart 28/30, f = -57.59134035621149
# Optimization restart 29/30, f = -57.59134056363892
# Optimization restart 30/30, f = -57.0894810503134
# design is [[ 0.1         2.          2.          0.1         0.1       ]
#  [ 0.16411933  2.         -1.1324215   0.1         0.1       ]
#  [ 0.4         2.         -2.          0.1         0.1       ]
#  [ 0.4         2.          2.          0.1         0.1       ]
#  [ 0.1         2.         -2.          0.4         0.4       ]]
# Working on design 2Working on design 1Working on design 3
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 5Working on design 4
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:42: RuntimeWarning:invalid value encountered in log
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:79: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:77: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:42: RuntimeWarning:invalid value encountered in log
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:79: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:77: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:42: RuntimeWarning:invalid value encountered in log
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:79: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:77: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
# For model parameters [0.4 2.  2.  0.1 0.1] takes 122.17025256156921 S
# For model parameters [ 0.4  2.  -2.   0.1  0.1] takes 183.1418812274933 S
# Total run time for the simulations 3.05 minutes
# Optimization restart 1/30, f = -60.57565374696287
# Optimization restart 2/30, f = -61.81487422582843
# Optimization restart 3/30, f = -61.814874225828945
# Optimization restart 4/30, f = -61.814874224869534
# Optimization restart 5/30, f = -61.81487422548218
# Optimization restart 6/30, f = -61.81487420112258
# Optimization restart 7/30, f = -61.81487422484618
# Optimization restart 8/30, f = -62.47611475929958
# Optimization restart 9/30, f = -62.476114796918395
# Optimization restart 10/30, f = -60.57565352775795
# Optimization restart 11/30, f = -61.814874223608214
# Optimization restart 12/30, f = -60.5756536754803
# Optimization restart 13/30, f = -61.814874212508336
# Optimization restart 14/30, f = -61.81487422467987
# Optimization restart 15/30, f = -61.81487422024834
# Optimization restart 16/30, f = -61.814874089805
# Optimization restart 17/30, f = -61.81487422510509
# Optimization restart 18/30, f = -61.814874225125195
# Optimization restart 19/30, f = -60.57565338386703
# Optimization restart 20/30, f = -61.814874173142215
# Optimization restart 21/30, f = -60.57565304531683
# Optimization restart 22/30, f = -61.814874225712046
# Optimization restart 23/30, f = -60.575653418360986
# Optimization restart 24/30, f = -60.57563686384344
# Optimization restart 25/30, f = -61.81487422546324
# Optimization restart 26/30, f = -60.57551017740318
# Optimization restart 27/30, f = -61.81487421836364
# Optimization restart 28/30, f = -60.57565341556878
# Optimization restart 29/30, f = -61.814874211632244
# Optimization restart 30/30, f = -61.81487422457349
# ######################
# AL After hyperparameters are
#
#
# Name : GP regression
# Objective : -62.476114796918395
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.36174985846744395  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.0016134277028042588  |      +ve      |
# ######################
# LHS before hyperparameters are
#
#
# Name : GP regression
# Objective : -68.9634000593829
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   rbf.variance             |   0.16379323262179743  |      +ve      |
#   rbf.lengthscale          |                  (5,)  |      +ve      |
#   Gaussian_noise.variance  |  5.37611365850458e-12  |      +ve      |
# Optimization restart 1/30, f = -69.99736132205425
# Optimization restart 2/30, f = -69.99736122439961
# Optimization restart 3/30, f = -69.99736136027407
# Optimization restart 4/30, f = -69.99736074262827
# Optimization restart 5/30, f = -69.99736082322815
# Optimization restart 6/30, f = -69.99736082940042
# Optimization restart 7/30, f = -63.99155983824838
# Optimization restart 8/30, f = -69.99736081498817
# Optimization restart 9/30, f = -69.99736004488925
# Optimization restart 10/30, f = -69.99736123308712
# Optimization restart 11/30, f = -69.99736087002002
# Optimization restart 12/30, f = -69.99736116608214
# Optimization restart 13/30, f = -69.99736119338093
# Optimization restart 14/30, f = -69.99736119295444
# Optimization restart 15/30, f = -69.99736117363844
# Optimization restart 16/30, f = -69.99736127572717
# Optimization restart 17/30, f = -69.99736135173684
# Optimization restart 18/30, f = -69.99736129460504
# Optimization restart 19/30, f = -69.99736078494209
# Optimization restart 20/30, f = -69.99736129065356
# Optimization restart 21/30, f = -69.99736122816117
# Optimization restart 22/30, f = -69.99736136347065
# Optimization restart 23/30, f = -69.99736126646752
# Optimization restart 24/30, f = -58.33543365473231
# Optimization restart 25/30, f = -69.99736136050296
# Optimization restart 26/30, f = -69.99736098642906
# Optimization restart 27/30, f = -69.99736136566726
# Optimization restart 28/30, f = -69.99736042102822
# Optimization restart 29/30, f = -63.96829455081735
# Optimization restart 30/30, f = -63.981079766608005
# ######################
# LHS After hyperparameters are
#
#
# Name : GP regression
# Objective : -69.99736136566726
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |     0.1552209159628052  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  4.222891166121062e-12  |      +ve      |
# time taken for the iteraton 0 is 192.59716606140137 S
# Working on design 1Working on design 2Working on design 3
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 5
#
# Working on design 4
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on design 6
# Working on design 7
# Working on design 8
# Working on design 9
# Working on design 10
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:42: RuntimeWarning:invalid value encountered in log
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:79: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:77: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
# For model parameters [ 0.37272727 -1.          1.          0.3         0.3       ] takes 66.33384990692139 S
# Total run time for the simulations 1.53 minutes
# Working on design 4Working on design 3
# Working on design 5
#
# Working on design 2Working on design 1
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on design 6
# Working on design 7
# Working on design 8
# Working on design 9
# Working on design 10
# Total run time for the simulations 0.86 minutes
# Working on design 3Working on design 4Working on design 5
#
#
# Working on design 2
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 1
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on design 6
# Working on design 7
# Working on design 8
# Working on design 9
# Working on design 10
# Total run time for the simulations 0.85 minutes
# Working on design 4Working on design 3Working on design 5
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 1Working on design 2
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on design 6
# Working on design 7
# Working on design 8
# Working on design 9
# Working on design 10
# Total run time for the simulations 0.85 minutes
# Working on design 3Working on design 4
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 5
# Working on design 1
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 2
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on design 6
# Working on design 7
# Working on design 8
# Working on design 9
# Working on design 10
# Total run time for the simulations 0.93 minutes
# ####################
#  ######################
# Validation score for 0 iteration AL 0.04889682112449148 , LHS 0.06095305374528853
# ######################
# AL before hyperparameters are
#
#
# Name : GP regression
# Objective : -62.476114796918395
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |    0.36174985846744395  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.0016134277028042588  |      +ve      |
# Optimization restart 1/30, f = -62.476114804317724
# Optimization restart 2/30, f = -61.81487422556983
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/paramz/transformations.py:111: RuntimeWarning:overflow encountered in expm1
# Optimization restart 3/30, f = -54.23707497105906
# Optimization restart 4/30, f = -60.57565363523523
# Optimization restart 5/30, f = -61.81487422489996
# Optimization restart 6/30, f = -61.81487422578729
# Optimization restart 7/30, f = -60.575046018483384
# Optimization restart 8/30, f = -61.814874225783385
# Optimization restart 9/30, f = -61.81487421319562
# Optimization restart 10/30, f = -60.5756535844144
# Optimization restart 11/30, f = -61.814874210826886
# Optimization restart 12/30, f = -61.81487422579511
# Optimization restart 13/30, f = -61.81487422550421
# Optimization restart 14/30, f = -61.81487422301434
# Optimization restart 15/30, f = -62.47611431699053
# Optimization restart 16/30, f = -61.81487421605431
# Optimization restart 17/30, f = -61.814874214487524
# Optimization restart 18/30, f = -60.57549058918015
# Optimization restart 19/30, f = -61.81487421540065
# Optimization restart 20/30, f = -61.81487421562402
# Optimization restart 21/30, f = -61.81487421708623
# Optimization restart 22/30, f = -61.81487422343741
# Optimization restart 23/30, f = -61.814874223382844
# Optimization restart 24/30, f = -60.57565370134442
# Optimization restart 25/30, f = -61.81487417726184
# Optimization restart 26/30, f = -61.81487421784438
# Optimization restart 27/30, f = -60.57565368124669
# Optimization restart 28/30, f = -61.814874225640224
# Optimization restart 29/30, f = -61.8148742062175
# Optimization restart 30/30, f = -61.81487420272295
# design is [[ 0.1        -2.          2.          0.4         0.12565897]
#  [ 0.1        -1.01935416  2.          0.1         0.2006975 ]
#  [ 0.26025069 -2.         -2.          0.1         0.25429144]
#  [ 0.1        -2.         -2.          0.4         0.28016429]
#  [ 0.35081332 -2.          2.          0.4         0.34804896]]
# Working on design 3Working on design 4Working on design 1Working on design 5Working on design 2
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:42: RuntimeWarning:invalid value encountered in log
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:79: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:77: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
# For model parameters [ 0.35081332 -2.          2.          0.4         0.34804896] takes 130.83772110939026 S
# Total run time for the simulations 2.18 minutes
# Optimization restart 1/30, f = -70.56425919931385
# Optimization restart 2/30, f = -70.36603964249773
# Optimization restart 3/30, f = -70.56425947625276
# Optimization restart 4/30, f = -70.3660397615662
# Optimization restart 5/30, f = -70.36603975332906
# Optimization restart 6/30, f = -70.36603975621352
# Optimization restart 7/30, f = -70.36603974710798
# Optimization restart 8/30, f = -70.36603976123057
# Optimization restart 9/30, f = -50.412663721047984
# Optimization restart 10/30, f = -70.36603974311285
# Optimization restart 11/30, f = -70.36603976516002
# Optimization restart 12/30, f = -69.27040528232209
# Optimization restart 13/30, f = -70.36603976273838
# Optimization restart 14/30, f = -70.36603976466218
# Optimization restart 15/30, f = -70.36603975651275
# Optimization restart 16/30, f = -69.26921720849427
# Optimization restart 17/30, f = -70.36603976268277
# Optimization restart 18/30, f = -70.36603976453512
# Optimization restart 19/30, f = -69.27044850989307
# Optimization restart 20/30, f = -70.36603975964194
# Optimization restart 21/30, f = -70.36603976314203
# Optimization restart 22/30, f = -70.3660397377677
# Optimization restart 23/30, f = -70.36603970158033
# Optimization restart 24/30, f = -70.36603973471371
# Optimization restart 25/30, f = -70.36603968707836
# Optimization restart 26/30, f = -70.36603972539504
# Optimization restart 27/30, f = -50.53774660324494
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/GPy/kern/src/stationary.py:137: RuntimeWarning:overflow encountered in square
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/GPy/kern/src/stationary.py:138: RuntimeWarning:invalid value encountered in add
# Optimization restart 28/30, f = -70.56425840562005
# Optimization restart 29/30, f = -70.36603976239978
# Optimization restart 30/30, f = -50.7425828651637
# ######################
# AL After hyperparameters are
#
#
# Name : GP regression
# Objective : -70.56425947625276
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   rbf.variance             |    0.3778752995530622  |      +ve      |
#   rbf.lengthscale          |                  (5,)  |      +ve      |
#   Gaussian_noise.variance  |  0.001329278531762902  |      +ve      |
# ######################
# LHS before hyperparameters are
#
#
# Name : GP regression
# Objective : -77.78270985568298
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   rbf.variance             |     0.1552209159628052  |      +ve      |
#   rbf.lengthscale          |                   (5,)  |      +ve      |
#   Gaussian_noise.variance  |  4.222891166121062e-12  |      +ve      |
# Optimization restart 1/30, f = -78.09545086814725
# Optimization restart 2/30, f = -77.87288206876279
# Optimization restart 3/30, f = -77.87288209902485
# Optimization restart 4/30, f = -77.87288205498561
# Optimization restart 5/30, f = -77.8728819835352
# Optimization restart 6/30, f = -77.87288210522269
# Optimization restart 7/30, f = -77.8728820665749
# Optimization restart 8/30, f = -77.87288209237035
# Optimization restart 9/30, f = -77.87288207807796
# Optimization restart 10/30, f = -77.87288209849194
# Optimization restart 11/30, f = -77.87288201531105
# Optimization restart 12/30, f = -77.87288210323273
# Optimization restart 13/30, f = -77.87288208928476
# Optimization restart 14/30, f = -77.87288209215808
# Optimization restart 15/30, f = -77.87288210672818
# Optimization restart 16/30, f = -77.87288209371971
# Optimization restart 17/30, f = -77.87288210479201
# Optimization restart 18/30, f = -77.87288209386293
# Optimization restart 19/30, f = -77.87288210545475
# Optimization restart 20/30, f = -77.87288209259304
# Optimization restart 21/30, f = -78.0954508684911
# Optimization restart 22/30, f = -77.87288210513165
# Optimization restart 23/30, f = -78.09538090249279
# Optimization restart 24/30, f = -77.87288209993005
# Optimization restart 25/30, f = -77.872882106864
# Optimization restart 26/30, f = -77.8728821000364
# Optimization restart 27/30, f = -77.87288210676897
# Optimization restart 28/30, f = -77.87288210681135
# Optimization restart 29/30, f = -77.87288210487061
# Optimization restart 30/30, f = -77.87288209100402
# ######################
# LHS After hyperparameters are
#
#
# Name : GP regression
# Objective : -78.0954508684911
# Number of Parameters : 7
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   rbf.variance             |   0.17899138148684696  |      +ve      |
#   rbf.lengthscale          |                  (5,)  |      +ve      |
#   Gaussian_noise.variance  |  4.11117617297582e-12  |      +ve      |
# time taken for the iteraton 1 is 138.97021913528442 S
# Working on design 5Working on design 3Working on design 4
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 1
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 2
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
# ...
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on design 6
# Working on design 7
# Working on design 8
# Working on design 9
# Working on design 10
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:42: RuntimeWarning:invalid value encountered in log
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:79: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:77: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:74: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:Extremely bad integrand behavior occurs at some points of the
#   integration interval.
# For model parameters [ 0.37272727 -1.          1.          0.3         0.3       ] takes 66.55622434616089 S
# Total run time for the simulations 1.54 minutes
# Working on design 4Working on design 5Working on design 3
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 1Working on design 2
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on design 6
# Working on design 7
# Working on design 8
# Working on design 9
# Working on design 10
# Total run time for the simulations 0.86 minutes
# Working on design 3Working on design 2Working on design 4
#
#
# Working on design 1Working on design 5
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on design 6
# Working on design 7
# Working on design 8
# Working on design 9
# Working on design 10
# Total run time for the simulations 0.85 minutes
# Working on design 5Working on design 4Working on design 3
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 2Working on design 1
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on design 6
# Working on design 7
# Working on design 8
# Working on design 9
# Working on design 10
# Total run time for the simulations 0.85 minutes
# Working on design 3Working on design 4
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 5
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
# Working on design 1Working on design 2
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: step size becomes too small
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/.conda/envs/parton_loss_owens/lib/python3.8/site-packages/scipy/integrate/_ode.py:1179: UserWarning:dopri5: larger nsteps is needed
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:78: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
#  /users/PAS0254/dananjaya/parton_energy_loss_qcd_bjorken/solver_rk.py:73: IntegrationWarning:The integral is probably divergent, or slowly convergent.
# Working on design 6
# Working on design 7
# Working on design 8
# Working on design 9
# Working on design 10
# Total run time for the simulations 0.92 minutes
# ####################
#  ######################
# Validation score for 9 iteration AL 0.03656122137662496 , LHS 0.029454507491935292

# %%
validation_array[:,0]
# Out:
# array([0.04889682, 0.04528194, 0.0421394 , 0.04040926, 0.0384757 ,
#        0.03744727, 0.03691861, 0.0352224 , 0.03776415, 0.03656122])

# %%
np.arange(55,105,5)
# Out:
# array([ 55,  60,  65,  70,  75,  80,  85,  90,  95, 100])

# %%
validation_array = np.array(validation_array)
fig, ax = plt.subplots()
n_train = np.arange(55,105,5)
ax.plot(n_train, validation_array[:,0], label = 'Active leraning max GP uncertainty')
ax.plot(n_train, validation_array[:,1], label = 'Lattin hypercube sampling')
ax.set_xticks(n_train)
ax.set_ylabel('RMSE')
ax.set_xlabel('Number of training points')
# Out:
# Text(0.5, 0, 'Number of training points')

# %%
time_ar = np.array(time_iter)
fig, ax = plt.subplots()
n_train = np.arange(55,105,5)
ax.plot(n_train, time_ar, label = 'Active leraning time')
ax.set_xticks(n_train)
ax.set_ylabel('Time/S')
ax.set_xlabel('Number of training points')
# Out:
# Text(0.5, 0, 'Number of training points')
